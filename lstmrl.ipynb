# %% [markdown]
# # RL Trading based on LSTM

# %%
import torch
import torch.nn as nn
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random

# %%
# def setup_seed(seed):
#     torch.manual_seed(seed)
#     torch.cuda.manual_seed_all(seed)
#     np.random.seed(seed)
#     random.seed(seed)
#     torch.backends.cudnn.deterministic = True
# # 设置随机数种子
# setup_seed(20)

# %% [markdown]
# ## 1. Loading data and data preprocessing

# %%
raw_prices = pd.read_csv("BTC.csv", header=None)
prices = np.array(raw_prices[1])
OFFSET = 200 #数据起始点
M = 25  #输入网络的历史窗口的大小，用于在每个时间步更新权重的历史大小
T = 2000 #交易者输入的时间序列长度
N = 600  #验证集大小
prices = prices[OFFSET:OFFSET+M+T+N+1]
asset_returns = torch.tensor(prices[1:] - prices[:-1]).to(torch.float32)
# asset_returns = torch.tensor((prices[1:] - prices[:-1]) / prices[:-1]).to(torch.float32)
print('asset_returns',asset_returns)
scaler = StandardScaler()
normalized_asset_returns = torch.tensor(scaler.fit_transform(asset_returns[:M+T][:, None])[:, 0]).to(torch.float32)
# Out:
# asset_returns tensor([-1.6900e+00, -6.6000e-01, -2.1400e+00,  ..., -2.0554e+03,
#         -1.2316e+02,  4.9195e+02])

# %% [markdown]
# ## 2. Create NN model

# %%
class LSTMRL(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim):
        super(LSTMRL, self).__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers

        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).requires_grad_().cuda()
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).requires_grad_().cuda()
        out, (hn, cn) = self.lstm(x, (h0.detach(), c0.detach()))
        out = self.fc(out[:, -1, :])
        return torch.tanh(out)

# %%
input_dim = 1
hidden_dim = 64
num_layers = 1
output_dim = 1
use_gpu = torch.cuda.is_available()
device = torch.device("cuda" if use_gpu else "cpu")
model = LSTMRL(input_dim=input_dim, hidden_dim=hidden_dim, output_dim=output_dim, num_layers=num_layers).to(device)
print(model)
# Out:
# LSTMRL(
#   (lstm): LSTM(1, 64, batch_first=True)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
# )

# %% [markdown]
# ## 3. Train the model

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
rewards = []
max_iter = 1000
miu = 1
delta = 0.04
eps = 1e-6

# %%
for epoch in range(max_iter):
    optimizer.zero_grad()
    Ft = torch.zeros(T).to(normalized_asset_returns.device)
    for i in range(1, T):
        data = normalized_asset_returns[i-1:i+M-1]
        input = data.view(1,M,1).to(device)
        Ft[i] = model(input)
    returns = miu * (Ft[:T-1] * asset_returns[M:M+T-1]) - (delta * torch.abs(Ft[1:] - Ft[:T-1]))
    expected_return = torch.mean(returns, dim=-1)
    std_return = torch.std(returns, dim=-1)
    sharpe = expected_return / (torch.sqrt(std_return) + eps)
    (-1 * sharpe).backward()
    optimizer.step()
    rewards.append(sharpe.detach().cpu())
    Cum_returns = returns.cumsum(dim=-1)
    print("Epoch ", epoch, "Sharpe: ", sharpe.detach().cpu())

print('Cum_return_train',Cum_returns[-1])
# Out:
# Epoch  0 Sharpe:  tensor(0.0889)
# Epoch  1 Sharpe:  tensor(0.1017)
# Epoch  2 Sharpe:  tensor(0.1134)
# Epoch  3 Sharpe:  tensor(0.1242)
# Epoch  4 Sharpe:  tensor(0.1345)
# Epoch  5 Sharpe:  tensor(0.1442)
# Epoch  6 Sharpe:  tensor(0.1535)
# Epoch  7 Sharpe:  tensor(0.1625)
# Epoch  8 Sharpe:  tensor(0.1712)
# Epoch  9 Sharpe:  tensor(0.1797)
# Epoch  10 Sharpe:  tensor(0.1882)
# Epoch  11 Sharpe:  tensor(0.1966)
# Epoch  12 Sharpe:  tensor(0.2050)
# Epoch  13 Sharpe:  tensor(0.2134)
# Epoch  14 Sharpe:  tensor(0.2220)
# Epoch  15 Sharpe:  tensor(0.2308)
# Epoch  16 Sharpe:  tensor(0.2398)
# Epoch  17 Sharpe:  tensor(0.2492)
# Epoch  18 Sharpe:  tensor(0.2591)
# Epoch  19 Sharpe:  tensor(0.2695)
# Epoch  20 Sharpe:  tensor(0.2807)
# Epoch  21 Sharpe:  tensor(0.2925)
# Epoch  22 Sharpe:  tensor(0.3051)
# Epoch  23 Sharpe:  tensor(0.3177)
# Epoch  24 Sharpe:  tensor(0.3296)
# Epoch  25 Sharpe:  tensor(0.3391)
# Epoch  26 Sharpe:  tensor(0.3455)
# Epoch  27 Sharpe:  tensor(0.3502)
# Epoch  28 Sharpe:  tensor(0.3565)
# Epoch  29 Sharpe:  tensor(0.3668)
# Epoch  30 Sharpe:  tensor(0.3817)
# Epoch  31 Sharpe:  tensor(0.4001)
# Epoch  32 Sharpe:  tensor(0.4196)
# Epoch  33 Sharpe:  tensor(0.4380)
# Epoch  34 Sharpe:  tensor(0.4545)
# Epoch  35 Sharpe:  tensor(0.4701)
# Epoch  36 Sharpe:  tensor(0.4867)
# Epoch  37 Sharpe:  tensor(0.5062)
# Epoch  38 Sharpe:  tensor(0.5283)
# Epoch  39 Sharpe:  tensor(0.5508)
# Epoch  40 Sharpe:  tensor(0.5709)
# Epoch  41 Sharpe:  tensor(0.5886)
# Epoch  42 Sharpe:  tensor(0.6057)
# Epoch  43 Sharpe:  tensor(0.6233)
# Epoch  44 Sharpe:  tensor(0.6427)
# Epoch  45 Sharpe:  tensor(0.6626)
# Epoch  46 Sharpe:  tensor(0.6734)
# Epoch  47 Sharpe:  tensor(0.6990)
# Epoch  48 Sharpe:  tensor(0.7286)
# Epoch  49 Sharpe:  tensor(0.7519)
# Epoch  50 Sharpe:  tensor(0.7900)
# Epoch  51 Sharpe:  tensor(0.7902)
# Epoch  52 Sharpe:  tensor(0.8028)
# Epoch  53 Sharpe:  tensor(0.8125)
# Epoch  54 Sharpe:  tensor(0.8441)
# Epoch  55 Sharpe:  tensor(0.8563)
# Epoch  56 Sharpe:  tensor(0.8524)
# Epoch  57 Sharpe:  tensor(0.8562)
# Epoch  58 Sharpe:  tensor(0.8694)
# Epoch  59 Sharpe:  tensor(0.8881)
# Epoch  60 Sharpe:  tensor(0.9042)
# Epoch  61 Sharpe:  tensor(0.9112)
# Epoch  62 Sharpe:  tensor(0.9255)
# Epoch  63 Sharpe:  tensor(0.9463)
# Epoch  64 Sharpe:  tensor(0.9508)
# Epoch  65 Sharpe:  tensor(0.9660)
# Epoch  66 Sharpe:  tensor(0.9748)
# Epoch  67 Sharpe:  tensor(1.0223)
# Epoch  68 Sharpe:  tensor(1.0883)
# Epoch  69 Sharpe:  tensor(0.9453)
# Epoch  70 Sharpe:  tensor(0.8588)
# Epoch  71 Sharpe:  tensor(0.7733)
# Epoch  72 Sharpe:  tensor(0.7879)
# Epoch  73 Sharpe:  tensor(0.6364)
# Epoch  74 Sharpe:  tensor(0.7214)
# Epoch  75 Sharpe:  tensor(0.8011)
# Epoch  76 Sharpe:  tensor(0.7970)
# Epoch  77 Sharpe:  tensor(0.7942)
# Epoch  78 Sharpe:  tensor(0.7992)
# Epoch  79 Sharpe:  tensor(0.8088)
# Epoch  80 Sharpe:  tensor(0.8961)
# Epoch  81 Sharpe:  tensor(0.8940)
# Epoch  82 Sharpe:  tensor(0.9057)
# Epoch  83 Sharpe:  tensor(0.9499)
# Epoch  84 Sharpe:  tensor(0.9670)
# Epoch  85 Sharpe:  tensor(1.0655)
# Epoch  86 Sharpe:  tensor(1.0937)
# Epoch  87 Sharpe:  tensor(1.1489)
# Epoch  88 Sharpe:  tensor(1.0946)
# Epoch  89 Sharpe:  tensor(1.1111)
# Epoch  90 Sharpe:  tensor(1.1254)
# Epoch  91 Sharpe:  tensor(1.2422)
# Epoch  92 Sharpe:  tensor(1.2757)
# Epoch  93 Sharpe:  tensor(1.3046)
# Epoch  94 Sharpe:  tensor(1.3195)
# Epoch  95 Sharpe:  tensor(1.0892)
# Epoch  96 Sharpe:  tensor(0.8324)
# Epoch  97 Sharpe:  tensor(0.8357)
# Epoch  98 Sharpe:  tensor(0.8109)
# Epoch  99 Sharpe:  tensor(0.7858)
# Epoch  100 Sharpe:  tensor(0.8138)
# Epoch  101 Sharpe:  tensor(0.7710)
# Epoch  102 Sharpe:  tensor(0.7718)
# Epoch  103 Sharpe:  tensor(0.8008)
# Epoch  104 Sharpe:  tensor(0.8094)
# Epoch  105 Sharpe:  tensor(0.8477)
# Epoch  106 Sharpe:  tensor(0.8272)
# Epoch  107 Sharpe:  tensor(0.8367)
# Epoch  108 Sharpe:  tensor(1.0366)
# Epoch  109 Sharpe:  tensor(1.2637)
# Epoch  110 Sharpe:  tensor(1.2627)
# Epoch  111 Sharpe:  tensor(1.1816)
# Epoch  112 Sharpe:  tensor(1.0528)
# Epoch  113 Sharpe:  tensor(1.0344)
# Epoch  114 Sharpe:  tensor(0.9704)
# Epoch  115 Sharpe:  tensor(0.9674)
# Epoch  116 Sharpe:  tensor(0.9343)
# Epoch  117 Sharpe:  tensor(0.8774)
# Epoch  118 Sharpe:  tensor(0.9232)
# Epoch  119 Sharpe:  tensor(0.9482)
# Epoch  120 Sharpe:  tensor(0.7506)
# Epoch  121 Sharpe:  tensor(0.7442)
# Epoch  122 Sharpe:  tensor(0.7520)
# Epoch  123 Sharpe:  tensor(0.7236)
# Epoch  124 Sharpe:  tensor(0.7311)
# Epoch  125 Sharpe:  tensor(0.7607)
# Epoch  126 Sharpe:  tensor(0.7516)
# Epoch  127 Sharpe:  tensor(0.7499)
# Epoch  128 Sharpe:  tensor(0.7510)
# Epoch  129 Sharpe:  tensor(0.7517)
# Epoch  130 Sharpe:  tensor(0.7573)
# Epoch  131 Sharpe:  tensor(0.8288)
# Epoch  132 Sharpe:  tensor(0.8305)
# Epoch  133 Sharpe:  tensor(0.9167)
# Epoch  134 Sharpe:  tensor(0.9118)
# Epoch  135 Sharpe:  tensor(0.9155)
# Epoch  136 Sharpe:  tensor(1.0061)
# Epoch  137 Sharpe:  tensor(1.0130)
# Epoch  138 Sharpe:  tensor(1.0016)
# Epoch  139 Sharpe:  tensor(1.0443)
# Epoch  140 Sharpe:  tensor(0.9568)
# Epoch  141 Sharpe:  tensor(0.9545)
# Epoch  142 Sharpe:  tensor(0.9714)
# Epoch  143 Sharpe:  tensor(0.9869)
# Epoch  144 Sharpe:  tensor(0.9899)
# Epoch  145 Sharpe:  tensor(0.8851)
# Epoch  146 Sharpe:  tensor(0.8859)
# Epoch  147 Sharpe:  tensor(0.8814)
# Epoch  148 Sharpe:  tensor(0.8807)
# Epoch  149 Sharpe:  tensor(0.8850)
# Epoch  150 Sharpe:  tensor(0.8917)
# Epoch  151 Sharpe:  tensor(0.8963)
# Epoch  152 Sharpe:  tensor(0.8967)
# Epoch  153 Sharpe:  tensor(0.8966)
# Epoch  154 Sharpe:  tensor(0.8980)
# Epoch  155 Sharpe:  tensor(0.9012)
# Epoch  156 Sharpe:  tensor(0.9057)
# Epoch  157 Sharpe:  tensor(0.9101)
# Epoch  158 Sharpe:  tensor(0.9122)
# Epoch  159 Sharpe:  tensor(0.9130)
# Epoch  160 Sharpe:  tensor(0.9147)
# Epoch  161 Sharpe:  tensor(0.9175)
# Epoch  162 Sharpe:  tensor(0.9214)
# Epoch  163 Sharpe:  tensor(0.9254)
# Epoch  164 Sharpe:  tensor(0.9277)
# Epoch  165 Sharpe:  tensor(0.9288)
# Epoch  166 Sharpe:  tensor(1.0433)
# Epoch  167 Sharpe:  tensor(1.1198)
# Epoch  168 Sharpe:  tensor(1.1119)
# Epoch  169 Sharpe:  tensor(1.1311)
# Epoch  170 Sharpe:  tensor(1.0550)
# Epoch  171 Sharpe:  tensor(1.0617)
# Epoch  172 Sharpe:  tensor(0.9538)
# Epoch  173 Sharpe:  tensor(0.8995)
# Epoch  174 Sharpe:  tensor(0.8993)
# Epoch  175 Sharpe:  tensor(0.8940)
# Epoch  176 Sharpe:  tensor(0.8939)
# Epoch  177 Sharpe:  tensor(0.8943)
# Epoch  178 Sharpe:  tensor(0.8955)
# Epoch  179 Sharpe:  tensor(0.8983)
# Epoch  180 Sharpe:  tensor(0.9042)
# Epoch  181 Sharpe:  tensor(0.9124)
# Epoch  182 Sharpe:  tensor(0.9187)
# Epoch  183 Sharpe:  tensor(0.9217)
# Epoch  184 Sharpe:  tensor(0.9281)
# Epoch  185 Sharpe:  tensor(0.9299)
# Epoch  186 Sharpe:  tensor(0.9316)
# Epoch  187 Sharpe:  tensor(0.9348)
# Epoch  188 Sharpe:  tensor(0.9395)
# Epoch  189 Sharpe:  tensor(0.9450)
# Epoch  190 Sharpe:  tensor(1.0218)
# Epoch  191 Sharpe:  tensor(1.0267)
# Epoch  192 Sharpe:  tensor(1.0290)
# Epoch  193 Sharpe:  tensor(1.0325)
# Epoch  194 Sharpe:  tensor(1.0347)
# Epoch  195 Sharpe:  tensor(1.0347)
# Epoch  196 Sharpe:  tensor(1.0372)
# Epoch  197 Sharpe:  tensor(1.0407)
# Epoch  198 Sharpe:  tensor(1.0433)
# Epoch  199 Sharpe:  tensor(1.0469)
# Epoch  200 Sharpe:  tensor(1.0508)
# Epoch  201 Sharpe:  tensor(1.0539)
# Epoch  202 Sharpe:  tensor(1.0561)
# Epoch  203 Sharpe:  tensor(1.0584)
# Epoch  204 Sharpe:  tensor(1.0606)
# Epoch  205 Sharpe:  tensor(1.0628)
# Epoch  206 Sharpe:  tensor(1.0653)
# Epoch  207 Sharpe:  tensor(1.0680)
# Epoch  208 Sharpe:  tensor(1.0712)
# Epoch  209 Sharpe:  tensor(1.0743)
# Epoch  210 Sharpe:  tensor(1.0771)
# Epoch  211 Sharpe:  tensor(1.0794)
# Epoch  212 Sharpe:  tensor(1.0813)
# Epoch  213 Sharpe:  tensor(1.0843)
# Epoch  214 Sharpe:  tensor(1.0874)
# Epoch  215 Sharpe:  tensor(1.2004)
# Epoch  216 Sharpe:  tensor(1.2732)
# Epoch  217 Sharpe:  tensor(1.2687)
# Epoch  218 Sharpe:  tensor(1.2781)
# Epoch  219 Sharpe:  tensor(1.2925)
# Epoch  220 Sharpe:  tensor(1.2961)
# Epoch  221 Sharpe:  tensor(1.2173)
# Epoch  222 Sharpe:  tensor(1.2214)
# Epoch  223 Sharpe:  tensor(1.2250)
# Epoch  224 Sharpe:  tensor(1.2283)
# Epoch  225 Sharpe:  tensor(1.2299)
# Epoch  226 Sharpe:  tensor(1.2321)
# Epoch  227 Sharpe:  tensor(1.2363)
# Epoch  228 Sharpe:  tensor(1.2414)
# Epoch  229 Sharpe:  tensor(1.2472)
# Epoch  230 Sharpe:  tensor(1.2518)
# Epoch  231 Sharpe:  tensor(1.2557)
# Epoch  232 Sharpe:  tensor(1.2612)
# Epoch  233 Sharpe:  tensor(1.2685)
# Epoch  234 Sharpe:  tensor(1.2742)
# Epoch  235 Sharpe:  tensor(1.2792)
# Epoch  236 Sharpe:  tensor(1.2867)
# Epoch  237 Sharpe:  tensor(1.2934)
# Epoch  238 Sharpe:  tensor(1.2986)
# Epoch  239 Sharpe:  tensor(1.3056)
# Epoch  240 Sharpe:  tensor(1.3100)
# Epoch  241 Sharpe:  tensor(1.3149)
# Epoch  242 Sharpe:  tensor(1.3208)
# Epoch  243 Sharpe:  tensor(1.3252)
# Epoch  244 Sharpe:  tensor(1.3307)
# Epoch  245 Sharpe:  tensor(1.3369)
# Epoch  246 Sharpe:  tensor(1.3414)
# Epoch  247 Sharpe:  tensor(1.3461)
# Epoch  248 Sharpe:  tensor(1.3493)
# Epoch  249 Sharpe:  tensor(1.3526)
# Epoch  250 Sharpe:  tensor(1.3561)
# Epoch  251 Sharpe:  tensor(1.3580)
# Epoch  252 Sharpe:  tensor(1.3611)
# Epoch  253 Sharpe:  tensor(1.3658)
# Epoch  254 Sharpe:  tensor(1.3688)
# Epoch  255 Sharpe:  tensor(1.3702)
# Epoch  256 Sharpe:  tensor(1.3724)
# Epoch  257 Sharpe:  tensor(1.3761)
# Epoch  258 Sharpe:  tensor(1.3826)
# Epoch  259 Sharpe:  tensor(1.3864)
# Epoch  260 Sharpe:  tensor(1.3875)
# Epoch  261 Sharpe:  tensor(1.3896)
# Epoch  262 Sharpe:  tensor(1.4787)
# Epoch  263 Sharpe:  tensor(1.4836)
# Epoch  264 Sharpe:  tensor(1.4862)
# Epoch  265 Sharpe:  tensor(1.4870)
# Epoch  266 Sharpe:  tensor(1.4887)
# Epoch  267 Sharpe:  tensor(1.4907)
# Epoch  268 Sharpe:  tensor(1.4945)
# Epoch  269 Sharpe:  tensor(1.4972)
# Epoch  270 Sharpe:  tensor(1.4993)
# Epoch  271 Sharpe:  tensor(1.4988)
# Epoch  272 Sharpe:  tensor(1.4941)
# Epoch  273 Sharpe:  tensor(1.4846)
# Epoch  274 Sharpe:  tensor(1.5105)
# Epoch  275 Sharpe:  tensor(1.4835)
# Epoch  276 Sharpe:  tensor(1.4829)
# Epoch  277 Sharpe:  tensor(1.4941)
# Epoch  278 Sharpe:  tensor(1.4738)
# Epoch  279 Sharpe:  tensor(1.5177)
# Epoch  280 Sharpe:  tensor(1.4819)
# Epoch  281 Sharpe:  tensor(1.4959)
# Epoch  282 Sharpe:  tensor(1.4964)
# Epoch  283 Sharpe:  tensor(1.5184)
# Epoch  284 Sharpe:  tensor(1.4985)
# Epoch  285 Sharpe:  tensor(1.5028)
# Epoch  286 Sharpe:  tensor(1.5209)
# Epoch  287 Sharpe:  tensor(1.5109)
# Epoch  288 Sharpe:  tensor(1.5172)
# Epoch  289 Sharpe:  tensor(1.5155)
# Epoch  290 Sharpe:  tensor(1.5255)
# Epoch  291 Sharpe:  tensor(1.5306)
# Epoch  292 Sharpe:  tensor(1.5226)
# Epoch  293 Sharpe:  tensor(1.5372)
# Epoch  294 Sharpe:  tensor(1.5214)
# Epoch  295 Sharpe:  tensor(1.5391)
# Epoch  296 Sharpe:  tensor(1.5349)
# Epoch  297 Sharpe:  tensor(1.5360)
# Epoch  298 Sharpe:  tensor(1.5459)
# Epoch  299 Sharpe:  tensor(1.5383)
# Epoch  300 Sharpe:  tensor(1.5475)
# Epoch  301 Sharpe:  tensor(1.5481)
# Epoch  302 Sharpe:  tensor(1.5459)
# Epoch  303 Sharpe:  tensor(1.5546)
# Epoch  304 Sharpe:  tensor(1.5521)
# Epoch  305 Sharpe:  tensor(1.5536)
# Epoch  306 Sharpe:  tensor(1.5601)
# Epoch  307 Sharpe:  tensor(1.5571)
# Epoch  308 Sharpe:  tensor(1.5604)
# Epoch  309 Sharpe:  tensor(1.5651)
# Epoch  310 Sharpe:  tensor(1.5630)
# Epoch  311 Sharpe:  tensor(1.5671)
# Epoch  312 Sharpe:  tensor(1.5701)
# Epoch  313 Sharpe:  tensor(1.5693)
# Epoch  314 Sharpe:  tensor(1.5736)
# Epoch  315 Sharpe:  tensor(1.5751)
# Epoch  316 Sharpe:  tensor(1.5757)
# Epoch  317 Sharpe:  tensor(1.5795)
# Epoch  318 Sharpe:  tensor(1.5799)
# Epoch  319 Sharpe:  tensor(1.5819)
# Epoch  320 Sharpe:  tensor(1.5843)
# Epoch  321 Sharpe:  tensor(1.5849)
# Epoch  322 Sharpe:  tensor(1.5876)
# Epoch  323 Sharpe:  tensor(1.5885)
# Epoch  324 Sharpe:  tensor(1.5906)
# Epoch  325 Sharpe:  tensor(1.5920)
# Epoch  326 Sharpe:  tensor(1.5936)
# Epoch  327 Sharpe:  tensor(1.5953)
# Epoch  328 Sharpe:  tensor(1.5970)
# Epoch  329 Sharpe:  tensor(1.5986)
# Epoch  330 Sharpe:  tensor(1.6002)
# Epoch  331 Sharpe:  tensor(1.6013)
# Epoch  332 Sharpe:  tensor(1.6009)
# Epoch  333 Sharpe:  tensor(1.6023)
# Epoch  334 Sharpe:  tensor(1.6036)
# Epoch  335 Sharpe:  tensor(1.5185)
# Epoch  336 Sharpe:  tensor(1.5189)
# Epoch  337 Sharpe:  tensor(1.5212)
# Epoch  338 Sharpe:  tensor(1.5228)
# Epoch  339 Sharpe:  tensor(1.5234)
# Epoch  340 Sharpe:  tensor(1.5273)
# Epoch  341 Sharpe:  tensor(1.5283)
# Epoch  342 Sharpe:  tensor(1.5302)
# Epoch  343 Sharpe:  tensor(1.5310)
# Epoch  344 Sharpe:  tensor(1.6162)
# Epoch  345 Sharpe:  tensor(1.6173)
# Epoch  346 Sharpe:  tensor(1.6179)
# Epoch  347 Sharpe:  tensor(1.6186)
# Epoch  348 Sharpe:  tensor(1.6194)
# Epoch  349 Sharpe:  tensor(1.6204)
# Epoch  350 Sharpe:  tensor(1.6214)
# Epoch  351 Sharpe:  tensor(1.6219)
# Epoch  352 Sharpe:  tensor(1.6227)
# Epoch  353 Sharpe:  tensor(1.6232)
# Epoch  354 Sharpe:  tensor(1.6236)
# Epoch  355 Sharpe:  tensor(1.6239)
# Epoch  356 Sharpe:  tensor(1.6243)
# Epoch  357 Sharpe:  tensor(1.6246)
# Epoch  358 Sharpe:  tensor(1.6249)
# Epoch  359 Sharpe:  tensor(1.6251)
# Epoch  360 Sharpe:  tensor(1.6254)
# Epoch  361 Sharpe:  tensor(1.6258)
# Epoch  362 Sharpe:  tensor(1.6262)
# Epoch  363 Sharpe:  tensor(1.6265)
# Epoch  364 Sharpe:  tensor(1.6268)
# Epoch  365 Sharpe:  tensor(1.6272)
# Epoch  366 Sharpe:  tensor(1.6275)
# Epoch  367 Sharpe:  tensor(1.6278)
# Epoch  368 Sharpe:  tensor(1.6280)
# Epoch  369 Sharpe:  tensor(1.6283)
# Epoch  370 Sharpe:  tensor(1.6286)
# Epoch  371 Sharpe:  tensor(1.6288)
# Epoch  372 Sharpe:  tensor(1.6291)
# Epoch  373 Sharpe:  tensor(1.6294)
# Epoch  374 Sharpe:  tensor(1.6296)
# Epoch  375 Sharpe:  tensor(1.6299)
# Epoch  376 Sharpe:  tensor(1.6301)
# Epoch  377 Sharpe:  tensor(1.6304)
# Epoch  378 Sharpe:  tensor(1.6307)
# Epoch  379 Sharpe:  tensor(1.6309)
# Epoch  380 Sharpe:  tensor(1.6312)
# Epoch  381 Sharpe:  tensor(1.6315)
# Epoch  382 Sharpe:  tensor(1.6318)
# Epoch  383 Sharpe:  tensor(1.6321)
# Epoch  384 Sharpe:  tensor(1.6324)
# Epoch  385 Sharpe:  tensor(1.6327)
# Epoch  386 Sharpe:  tensor(1.6331)
# Epoch  387 Sharpe:  tensor(1.6334)
# Epoch  388 Sharpe:  tensor(1.6338)
# Epoch  389 Sharpe:  tensor(1.6342)
# Epoch  390 Sharpe:  tensor(1.6347)
# Epoch  391 Sharpe:  tensor(1.6351)
# Epoch  392 Sharpe:  tensor(1.6356)
# Epoch  393 Sharpe:  tensor(1.6362)
# Epoch  394 Sharpe:  tensor(1.6368)
# Epoch  395 Sharpe:  tensor(1.6374)
# Epoch  396 Sharpe:  tensor(1.6381)
# Epoch  397 Sharpe:  tensor(1.6389)
# Epoch  398 Sharpe:  tensor(1.6398)
# Epoch  399 Sharpe:  tensor(1.6407)
# Epoch  400 Sharpe:  tensor(1.6418)
# Epoch  401 Sharpe:  tensor(1.6429)
# Epoch  402 Sharpe:  tensor(1.6442)
# Epoch  403 Sharpe:  tensor(1.6455)
# Epoch  404 Sharpe:  tensor(1.6468)
# Epoch  405 Sharpe:  tensor(1.6484)
# Epoch  406 Sharpe:  tensor(1.6496)
# Epoch  407 Sharpe:  tensor(1.6516)
# Epoch  408 Sharpe:  tensor(1.6509)
# Epoch  409 Sharpe:  tensor(1.5527)
# Epoch  410 Sharpe:  tensor(1.5563)
# Epoch  411 Sharpe:  tensor(1.5944)
# Epoch  412 Sharpe:  tensor(1.5934)
# Epoch  413 Sharpe:  tensor(1.5081)
# Epoch  414 Sharpe:  tensor(1.4866)
# Epoch  415 Sharpe:  tensor(1.3853)
# Epoch  416 Sharpe:  tensor(1.5011)
# Epoch  417 Sharpe:  tensor(1.5092)
# Epoch  418 Sharpe:  tensor(1.3141)
# Epoch  419 Sharpe:  tensor(1.2281)
# Epoch  420 Sharpe:  tensor(1.1374)
# Epoch  421 Sharpe:  tensor(1.0634)
# Epoch  422 Sharpe:  tensor(1.0625)
# Epoch  423 Sharpe:  tensor(1.1004)
# Epoch  424 Sharpe:  tensor(1.1606)
# Epoch  425 Sharpe:  tensor(1.2066)
# Epoch  426 Sharpe:  tensor(1.3839)
# Epoch  427 Sharpe:  tensor(1.2996)
# Epoch  428 Sharpe:  tensor(1.4372)
# Epoch  429 Sharpe:  tensor(1.4913)
# Epoch  430 Sharpe:  tensor(1.4442)
# Epoch  431 Sharpe:  tensor(1.5443)
# Epoch  432 Sharpe:  tensor(1.5529)
# Epoch  433 Sharpe:  tensor(1.5901)
# Epoch  434 Sharpe:  tensor(1.5973)
# Epoch  435 Sharpe:  tensor(1.5937)
# Epoch  436 Sharpe:  tensor(1.5890)
# Epoch  437 Sharpe:  tensor(1.5567)
# Epoch  438 Sharpe:  tensor(1.5755)
# Epoch  439 Sharpe:  tensor(1.5027)
# Epoch  440 Sharpe:  tensor(1.4418)
# Epoch  441 Sharpe:  tensor(1.3426)
# Epoch  442 Sharpe:  tensor(1.3843)
# Epoch  443 Sharpe:  tensor(1.4963)
# Epoch  444 Sharpe:  tensor(1.4815)
# Epoch  445 Sharpe:  tensor(1.4730)
# Epoch  446 Sharpe:  tensor(1.5526)
# Epoch  447 Sharpe:  tensor(1.5952)
# Epoch  448 Sharpe:  tensor(1.6502)
# Epoch  449 Sharpe:  tensor(1.6752)
# Epoch  450 Sharpe:  tensor(1.6699)
# Epoch  451 Sharpe:  tensor(1.6741)
# Epoch  452 Sharpe:  tensor(1.6729)
# Epoch  453 Sharpe:  tensor(1.6751)
# Epoch  454 Sharpe:  tensor(1.6284)
# Epoch  455 Sharpe:  tensor(1.6185)
# Epoch  456 Sharpe:  tensor(1.6182)
# Epoch  457 Sharpe:  tensor(1.6193)
# Epoch  458 Sharpe:  tensor(1.6200)
# Epoch  459 Sharpe:  tensor(1.6203)
# Epoch  460 Sharpe:  tensor(1.6210)
# Epoch  461 Sharpe:  tensor(1.6218)
# Epoch  462 Sharpe:  tensor(1.6230)
# Epoch  463 Sharpe:  tensor(1.6241)
# Epoch  464 Sharpe:  tensor(1.6251)
# Epoch  465 Sharpe:  tensor(1.6046)
# Epoch  466 Sharpe:  tensor(1.6068)
# Epoch  467 Sharpe:  tensor(1.6129)
# Epoch  468 Sharpe:  tensor(1.6279)
# Epoch  469 Sharpe:  tensor(1.6400)
# Epoch  470 Sharpe:  tensor(1.6465)
# Epoch  471 Sharpe:  tensor(1.6479)
# Epoch  472 Sharpe:  tensor(1.6657)
# Epoch  473 Sharpe:  tensor(1.6311)
# Epoch  474 Sharpe:  tensor(1.6617)
# Epoch  475 Sharpe:  tensor(1.6420)
# Epoch  476 Sharpe:  tensor(1.6786)
# Epoch  477 Sharpe:  tensor(1.6376)
# Epoch  478 Sharpe:  tensor(1.7227)
# Epoch  479 Sharpe:  tensor(1.7010)
# Epoch  480 Sharpe:  tensor(1.7038)
# Epoch  481 Sharpe:  tensor(1.7175)
# Epoch  482 Sharpe:  tensor(1.7006)
# Epoch  483 Sharpe:  tensor(1.6307)
# Epoch  484 Sharpe:  tensor(1.5227)
# Epoch  485 Sharpe:  tensor(1.6537)
# Epoch  486 Sharpe:  tensor(1.5670)
# Epoch  487 Sharpe:  tensor(1.6140)
# Epoch  488 Sharpe:  tensor(1.6921)
# Epoch  489 Sharpe:  tensor(1.6676)
# Epoch  490 Sharpe:  tensor(1.6568)
# Epoch  491 Sharpe:  tensor(1.6250)
# Epoch  492 Sharpe:  tensor(1.6192)
# Epoch  493 Sharpe:  tensor(1.6216)
# Epoch  494 Sharpe:  tensor(1.6247)
# Epoch  495 Sharpe:  tensor(1.6363)
# Epoch  496 Sharpe:  tensor(1.6395)
# Epoch  497 Sharpe:  tensor(1.6416)
# Epoch  498 Sharpe:  tensor(1.6426)
# Epoch  499 Sharpe:  tensor(1.6438)
# Epoch  500 Sharpe:  tensor(1.6670)
# Epoch  501 Sharpe:  tensor(1.6805)
# Epoch  502 Sharpe:  tensor(1.7063)
# Epoch  503 Sharpe:  tensor(1.7100)
# Epoch  504 Sharpe:  tensor(1.7066)
# Epoch  505 Sharpe:  tensor(1.7085)
# Epoch  506 Sharpe:  tensor(1.7097)
# Epoch  507 Sharpe:  tensor(1.6956)
# Epoch  508 Sharpe:  tensor(1.6997)
# Epoch  509 Sharpe:  tensor(1.7033)
# Epoch  510 Sharpe:  tensor(1.7058)
# Epoch  511 Sharpe:  tensor(1.7068)
# Epoch  512 Sharpe:  tensor(1.7066)
# Epoch  513 Sharpe:  tensor(1.7091)
# Epoch  514 Sharpe:  tensor(1.7086)
# Epoch  515 Sharpe:  tensor(1.7014)
# Epoch  516 Sharpe:  tensor(1.7157)
# Epoch  517 Sharpe:  tensor(1.7162)
# Epoch  518 Sharpe:  tensor(1.7167)
# Epoch  519 Sharpe:  tensor(1.7222)
# Epoch  520 Sharpe:  tensor(1.7194)
# Epoch  521 Sharpe:  tensor(1.7177)
# Epoch  522 Sharpe:  tensor(1.7221)
# Epoch  523 Sharpe:  tensor(1.7205)
# Epoch  524 Sharpe:  tensor(1.7222)
# Epoch  525 Sharpe:  tensor(1.7245)
# Epoch  526 Sharpe:  tensor(1.7242)
# Epoch  527 Sharpe:  tensor(1.7238)
# Epoch  528 Sharpe:  tensor(1.7246)
# Epoch  529 Sharpe:  tensor(1.7254)
# Epoch  530 Sharpe:  tensor(1.7257)
# Epoch  531 Sharpe:  tensor(1.7256)
# Epoch  532 Sharpe:  tensor(1.7255)
# Epoch  533 Sharpe:  tensor(1.7257)
# Epoch  534 Sharpe:  tensor(1.7262)
# Epoch  535 Sharpe:  tensor(1.7265)
# Epoch  536 Sharpe:  tensor(1.7266)
# Epoch  537 Sharpe:  tensor(1.7266)
# Epoch  538 Sharpe:  tensor(1.7267)
# Epoch  539 Sharpe:  tensor(1.7269)
# Epoch  540 Sharpe:  tensor(1.7271)
# Epoch  541 Sharpe:  tensor(1.7272)
# Epoch  542 Sharpe:  tensor(1.7246)
# Epoch  543 Sharpe:  tensor(1.7246)
# Epoch  544 Sharpe:  tensor(1.7262)
# Epoch  545 Sharpe:  tensor(1.7263)
# Epoch  546 Sharpe:  tensor(1.7264)
# Epoch  547 Sharpe:  tensor(1.7265)
# Epoch  548 Sharpe:  tensor(1.7250)
# Epoch  549 Sharpe:  tensor(1.7267)
# Epoch  550 Sharpe:  tensor(1.7267)
# Epoch  551 Sharpe:  tensor(1.7267)
# Epoch  552 Sharpe:  tensor(1.7268)
# Epoch  553 Sharpe:  tensor(1.7269)
# Epoch  554 Sharpe:  tensor(1.7269)
# Epoch  555 Sharpe:  tensor(1.7270)
# Epoch  556 Sharpe:  tensor(1.7270)
# Epoch  557 Sharpe:  tensor(1.7271)
# Epoch  558 Sharpe:  tensor(1.7271)
# Epoch  559 Sharpe:  tensor(1.7272)
# Epoch  560 Sharpe:  tensor(1.7272)
# Epoch  561 Sharpe:  tensor(1.7273)
# Epoch  562 Sharpe:  tensor(1.7273)
# Epoch  563 Sharpe:  tensor(1.7274)
# Epoch  564 Sharpe:  tensor(1.7274)
# Epoch  565 Sharpe:  tensor(1.7274)
# Epoch  566 Sharpe:  tensor(1.7275)
# Epoch  567 Sharpe:  tensor(1.7275)
# Epoch  568 Sharpe:  tensor(1.7275)
# Epoch  569 Sharpe:  tensor(1.7276)
# Epoch  570 Sharpe:  tensor(1.7276)
# Epoch  571 Sharpe:  tensor(1.7276)
# Epoch  572 Sharpe:  tensor(1.7277)
# Epoch  573 Sharpe:  tensor(1.7277)
# Epoch  574 Sharpe:  tensor(1.7277)
# Epoch  575 Sharpe:  tensor(1.7278)
# Epoch  576 Sharpe:  tensor(1.7278)
# Epoch  577 Sharpe:  tensor(1.7278)
# Epoch  578 Sharpe:  tensor(1.7278)
# Epoch  579 Sharpe:  tensor(1.7279)
# Epoch  580 Sharpe:  tensor(1.7279)
# Epoch  581 Sharpe:  tensor(1.7279)
# Epoch  582 Sharpe:  tensor(1.7280)
# Epoch  583 Sharpe:  tensor(1.7280)
# Epoch  584 Sharpe:  tensor(1.7280)
# Epoch  585 Sharpe:  tensor(1.7280)
# Epoch  586 Sharpe:  tensor(1.7280)
# Epoch  587 Sharpe:  tensor(1.7281)
# Epoch  588 Sharpe:  tensor(1.7281)
# Epoch  589 Sharpe:  tensor(1.7281)
# Epoch  590 Sharpe:  tensor(1.7281)
# Epoch  591 Sharpe:  tensor(1.7282)
# Epoch  592 Sharpe:  tensor(1.7282)
# Epoch  593 Sharpe:  tensor(1.7282)
# Epoch  594 Sharpe:  tensor(1.7282)
# Epoch  595 Sharpe:  tensor(1.7283)
# Epoch  596 Sharpe:  tensor(1.7283)
# Epoch  597 Sharpe:  tensor(1.7283)
# Epoch  598 Sharpe:  tensor(1.7283)
# Epoch  599 Sharpe:  tensor(1.7283)
# Epoch  600 Sharpe:  tensor(1.7284)
# Epoch  601 Sharpe:  tensor(1.7284)
# Epoch  602 Sharpe:  tensor(1.7284)
# Epoch  603 Sharpe:  tensor(1.7284)
# Epoch  604 Sharpe:  tensor(1.7284)
# Epoch  605 Sharpe:  tensor(1.7284)
# Epoch  606 Sharpe:  tensor(1.7285)
# Epoch  607 Sharpe:  tensor(1.7285)
# Epoch  608 Sharpe:  tensor(1.7285)
# Epoch  609 Sharpe:  tensor(1.7285)
# Epoch  610 Sharpe:  tensor(1.7285)
# Epoch  611 Sharpe:  tensor(1.7286)
# Epoch  612 Sharpe:  tensor(1.7286)
# Epoch  613 Sharpe:  tensor(1.7286)
# Epoch  614 Sharpe:  tensor(1.7286)
# Epoch  615 Sharpe:  tensor(1.7286)
# Epoch  616 Sharpe:  tensor(1.7286)
# Epoch  617 Sharpe:  tensor(1.7287)
# Epoch  618 Sharpe:  tensor(1.7368)
# Epoch  619 Sharpe:  tensor(1.7368)
# Epoch  620 Sharpe:  tensor(1.7368)
# Epoch  621 Sharpe:  tensor(1.7287)
# Epoch  622 Sharpe:  tensor(1.7298)
# Epoch  623 Sharpe:  tensor(1.7296)
# Epoch  624 Sharpe:  tensor(1.7292)
# Epoch  625 Sharpe:  tensor(1.7293)
# Epoch  626 Sharpe:  tensor(1.7296)
# Epoch  627 Sharpe:  tensor(1.7297)
# Epoch  628 Sharpe:  tensor(1.7297)
# Epoch  629 Sharpe:  tensor(1.7295)
# Epoch  630 Sharpe:  tensor(1.7295)
# Epoch  631 Sharpe:  tensor(1.7296)
# Epoch  632 Sharpe:  tensor(1.7297)
# Epoch  633 Sharpe:  tensor(1.7298)
# Epoch  634 Sharpe:  tensor(1.7299)
# Epoch  635 Sharpe:  tensor(1.7300)
# Epoch  636 Sharpe:  tensor(1.7299)
# Epoch  637 Sharpe:  tensor(1.7299)
# Epoch  638 Sharpe:  tensor(1.7299)
# Epoch  639 Sharpe:  tensor(1.7299)
# Epoch  640 Sharpe:  tensor(1.7299)
# Epoch  641 Sharpe:  tensor(1.7300)
# Epoch  642 Sharpe:  tensor(1.7300)
# Epoch  643 Sharpe:  tensor(1.7301)
# Epoch  644 Sharpe:  tensor(1.7301)
# Epoch  645 Sharpe:  tensor(1.7301)
# Epoch  646 Sharpe:  tensor(1.7301)
# Epoch  647 Sharpe:  tensor(1.7301)
# Epoch  648 Sharpe:  tensor(1.7301)
# Epoch  649 Sharpe:  tensor(1.7301)
# Epoch  650 Sharpe:  tensor(1.7302)
# Epoch  651 Sharpe:  tensor(1.7302)
# Epoch  652 Sharpe:  tensor(1.7302)
# Epoch  653 Sharpe:  tensor(1.7302)
# Epoch  654 Sharpe:  tensor(1.7302)
# Epoch  655 Sharpe:  tensor(1.7303)
# Epoch  656 Sharpe:  tensor(1.7303)
# Epoch  657 Sharpe:  tensor(1.7303)
# Epoch  658 Sharpe:  tensor(1.7303)
# Epoch  659 Sharpe:  tensor(1.7303)
# Epoch  660 Sharpe:  tensor(1.7303)
# Epoch  661 Sharpe:  tensor(1.7303)
# Epoch  662 Sharpe:  tensor(1.7303)
# Epoch  663 Sharpe:  tensor(1.7304)
# Epoch  664 Sharpe:  tensor(1.7304)
# Epoch  665 Sharpe:  tensor(1.7304)
# Epoch  666 Sharpe:  tensor(1.7304)
# Epoch  667 Sharpe:  tensor(1.7304)
# Epoch  668 Sharpe:  tensor(1.7304)
# Epoch  669 Sharpe:  tensor(1.7304)
# Epoch  670 Sharpe:  tensor(1.7304)
# Epoch  671 Sharpe:  tensor(1.7304)
# Epoch  672 Sharpe:  tensor(1.7305)
# Epoch  673 Sharpe:  tensor(1.7305)
# Epoch  674 Sharpe:  tensor(1.7305)
# Epoch  675 Sharpe:  tensor(1.7305)
# Epoch  676 Sharpe:  tensor(1.7305)
# Epoch  677 Sharpe:  tensor(1.7305)
# Epoch  678 Sharpe:  tensor(1.7305)
# Epoch  679 Sharpe:  tensor(1.7305)
# Epoch  680 Sharpe:  tensor(1.7305)
# Epoch  681 Sharpe:  tensor(1.7306)
# Epoch  682 Sharpe:  tensor(1.7306)
# Epoch  683 Sharpe:  tensor(1.7306)
# Epoch  684 Sharpe:  tensor(1.7306)
# Epoch  685 Sharpe:  tensor(1.7306)
# Epoch  686 Sharpe:  tensor(1.7306)
# Epoch  687 Sharpe:  tensor(1.7306)
# Epoch  688 Sharpe:  tensor(1.7306)
# Epoch  689 Sharpe:  tensor(1.7306)
# Epoch  690 Sharpe:  tensor(1.7307)
# Epoch  691 Sharpe:  tensor(1.7307)
# Epoch  692 Sharpe:  tensor(1.7307)
# Epoch  693 Sharpe:  tensor(1.7307)
# Epoch  694 Sharpe:  tensor(1.7307)
# Epoch  695 Sharpe:  tensor(1.7307)
# Epoch  696 Sharpe:  tensor(1.7307)
# Epoch  697 Sharpe:  tensor(1.7307)
# Epoch  698 Sharpe:  tensor(1.7307)
# Epoch  699 Sharpe:  tensor(1.7307)
# Epoch  700 Sharpe:  tensor(1.7307)
# Epoch  701 Sharpe:  tensor(1.7308)
# Epoch  702 Sharpe:  tensor(1.7308)
# Epoch  703 Sharpe:  tensor(1.7308)
# Epoch  704 Sharpe:  tensor(1.7308)
# Epoch  705 Sharpe:  tensor(1.7308)
# Epoch  706 Sharpe:  tensor(1.7308)
# Epoch  707 Sharpe:  tensor(1.7308)
# Epoch  708 Sharpe:  tensor(1.7308)
# Epoch  709 Sharpe:  tensor(1.7308)
# Epoch  710 Sharpe:  tensor(1.7308)
# Epoch  711 Sharpe:  tensor(1.7308)
# Epoch  712 Sharpe:  tensor(1.7308)
# Epoch  713 Sharpe:  tensor(1.7309)
# Epoch  714 Sharpe:  tensor(1.7309)
# Epoch  715 Sharpe:  tensor(1.7309)
# Epoch  716 Sharpe:  tensor(1.7309)
# Epoch  717 Sharpe:  tensor(1.7309)
# Epoch  718 Sharpe:  tensor(1.7309)
# Epoch  719 Sharpe:  tensor(1.7309)
# Epoch  720 Sharpe:  tensor(1.7309)
# Epoch  721 Sharpe:  tensor(1.7309)
# Epoch  722 Sharpe:  tensor(1.7309)
# Epoch  723 Sharpe:  tensor(1.7309)
# Epoch  724 Sharpe:  tensor(1.7309)
# Epoch  725 Sharpe:  tensor(1.7310)
# Epoch  726 Sharpe:  tensor(1.7310)
# Epoch  727 Sharpe:  tensor(1.7310)
# Epoch  728 Sharpe:  tensor(1.7310)
# Epoch  729 Sharpe:  tensor(1.7310)
# Epoch  730 Sharpe:  tensor(1.7310)
# Epoch  731 Sharpe:  tensor(1.7310)
# Epoch  732 Sharpe:  tensor(1.7310)
# Epoch  733 Sharpe:  tensor(1.7310)
# Epoch  734 Sharpe:  tensor(1.7310)
# Epoch  735 Sharpe:  tensor(1.7310)
# Epoch  736 Sharpe:  tensor(1.7310)
# Epoch  737 Sharpe:  tensor(1.7310)
# Epoch  738 Sharpe:  tensor(1.7311)
# Epoch  739 Sharpe:  tensor(1.7311)
# Epoch  740 Sharpe:  tensor(1.7311)
# Epoch  741 Sharpe:  tensor(1.7311)
# Epoch  742 Sharpe:  tensor(1.7311)
# Epoch  743 Sharpe:  tensor(1.7311)
# Epoch  744 Sharpe:  tensor(1.7311)
# Epoch  745 Sharpe:  tensor(1.7311)
# Epoch  746 Sharpe:  tensor(1.7311)
# Epoch  747 Sharpe:  tensor(1.7311)
# Epoch  748 Sharpe:  tensor(1.7311)
# Epoch  749 Sharpe:  tensor(1.7311)
# Epoch  750 Sharpe:  tensor(1.7311)
# Epoch  751 Sharpe:  tensor(1.7311)
# Epoch  752 Sharpe:  tensor(1.7311)
# Epoch  753 Sharpe:  tensor(1.7312)
# Epoch  754 Sharpe:  tensor(1.7312)
# Epoch  755 Sharpe:  tensor(1.7312)
# Epoch  756 Sharpe:  tensor(1.7312)
# Epoch  757 Sharpe:  tensor(1.7312)
# Epoch  758 Sharpe:  tensor(1.7312)
# Epoch  759 Sharpe:  tensor(1.7312)
# Epoch  760 Sharpe:  tensor(1.7312)
# Epoch  761 Sharpe:  tensor(1.7312)
# Epoch  762 Sharpe:  tensor(1.7312)
# Epoch  763 Sharpe:  tensor(1.7312)
# Epoch  764 Sharpe:  tensor(1.7312)
# Epoch  765 Sharpe:  tensor(1.7312)
# Epoch  766 Sharpe:  tensor(1.7312)
# Epoch  767 Sharpe:  tensor(1.7312)
# Epoch  768 Sharpe:  tensor(1.7313)
# Epoch  769 Sharpe:  tensor(1.7313)
# Epoch  770 Sharpe:  tensor(1.7313)
# Epoch  771 Sharpe:  tensor(1.7313)
# Epoch  772 Sharpe:  tensor(1.7313)
# Epoch  773 Sharpe:  tensor(1.7313)
# Epoch  774 Sharpe:  tensor(1.7313)
# Epoch  775 Sharpe:  tensor(1.7313)
# Epoch  776 Sharpe:  tensor(1.7313)
# Epoch  777 Sharpe:  tensor(1.7313)
# Epoch  778 Sharpe:  tensor(1.7313)
# Epoch  779 Sharpe:  tensor(1.7313)
# Epoch  780 Sharpe:  tensor(1.7313)
# Epoch  781 Sharpe:  tensor(1.7313)
# Epoch  782 Sharpe:  tensor(1.7313)
# Epoch  783 Sharpe:  tensor(1.7313)
# Epoch  784 Sharpe:  tensor(1.7313)
# Epoch  785 Sharpe:  tensor(1.7314)
# Epoch  786 Sharpe:  tensor(1.7314)
# Epoch  787 Sharpe:  tensor(1.7314)
# Epoch  788 Sharpe:  tensor(1.7314)
# Epoch  789 Sharpe:  tensor(1.7314)
# Epoch  790 Sharpe:  tensor(1.7314)
# Epoch  791 Sharpe:  tensor(1.7314)
# Epoch  792 Sharpe:  tensor(1.7314)
# Epoch  793 Sharpe:  tensor(1.7314)
# Epoch  794 Sharpe:  tensor(1.7314)
# Epoch  795 Sharpe:  tensor(1.7314)
# Epoch  796 Sharpe:  tensor(1.7314)
# Epoch  797 Sharpe:  tensor(1.7314)
# Epoch  798 Sharpe:  tensor(1.7314)
# Epoch  799 Sharpe:  tensor(1.7314)
# Epoch  800 Sharpe:  tensor(1.7314)
# Epoch  801 Sharpe:  tensor(1.7314)
# Epoch  802 Sharpe:  tensor(1.7314)
# Epoch  803 Sharpe:  tensor(1.7314)
# Epoch  804 Sharpe:  tensor(1.7315)
# Epoch  805 Sharpe:  tensor(1.7315)
# Epoch  806 Sharpe:  tensor(1.7315)
# Epoch  807 Sharpe:  tensor(1.7315)
# Epoch  808 Sharpe:  tensor(1.7315)
# Epoch  809 Sharpe:  tensor(1.7315)
# Epoch  810 Sharpe:  tensor(1.7315)
# Epoch  811 Sharpe:  tensor(1.7315)
# Epoch  812 Sharpe:  tensor(1.7315)
# Epoch  813 Sharpe:  tensor(1.7315)
# Epoch  814 Sharpe:  tensor(1.7315)
# Epoch  815 Sharpe:  tensor(1.7315)
# Epoch  816 Sharpe:  tensor(1.7315)
# Epoch  817 Sharpe:  tensor(1.7315)
# Epoch  818 Sharpe:  tensor(1.7315)
# Epoch  819 Sharpe:  tensor(1.7315)
# Epoch  820 Sharpe:  tensor(1.7315)
# Epoch  821 Sharpe:  tensor(1.7315)
# Epoch  822 Sharpe:  tensor(1.7315)
# Epoch  823 Sharpe:  tensor(1.7315)
# Epoch  824 Sharpe:  tensor(1.7316)
# Epoch  825 Sharpe:  tensor(1.7316)
# Epoch  826 Sharpe:  tensor(1.7316)
# Epoch  827 Sharpe:  tensor(1.7316)
# Epoch  828 Sharpe:  tensor(1.7316)
# Epoch  829 Sharpe:  tensor(1.7316)
# Epoch  830 Sharpe:  tensor(1.7316)
# Epoch  831 Sharpe:  tensor(1.7316)
# Epoch  832 Sharpe:  tensor(1.7316)
# Epoch  833 Sharpe:  tensor(1.7316)
# Epoch  834 Sharpe:  tensor(1.7316)
# Epoch  835 Sharpe:  tensor(1.7316)
# Epoch  836 Sharpe:  tensor(1.7316)
# Epoch  837 Sharpe:  tensor(1.7316)
# Epoch  838 Sharpe:  tensor(1.7316)
# Epoch  839 Sharpe:  tensor(1.7316)
# Epoch  840 Sharpe:  tensor(1.7316)
# Epoch  841 Sharpe:  tensor(1.7316)
# Epoch  842 Sharpe:  tensor(1.7316)
# Epoch  843 Sharpe:  tensor(1.7316)
# Epoch  844 Sharpe:  tensor(1.7316)
# Epoch  845 Sharpe:  tensor(1.7316)
# Epoch  846 Sharpe:  tensor(1.7316)
# Epoch  847 Sharpe:  tensor(1.7317)
# Epoch  848 Sharpe:  tensor(1.7317)
# Epoch  849 Sharpe:  tensor(1.7317)
# Epoch  850 Sharpe:  tensor(1.7317)
# Epoch  851 Sharpe:  tensor(1.7317)
# Epoch  852 Sharpe:  tensor(1.7317)
# Epoch  853 Sharpe:  tensor(1.7317)
# Epoch  854 Sharpe:  tensor(1.7317)
# Epoch  855 Sharpe:  tensor(1.7317)
# Epoch  856 Sharpe:  tensor(1.7317)
# Epoch  857 Sharpe:  tensor(1.7317)
# Epoch  858 Sharpe:  tensor(1.7317)
# Epoch  859 Sharpe:  tensor(1.7317)
# Epoch  860 Sharpe:  tensor(1.7317)
# Epoch  861 Sharpe:  tensor(1.7317)
# Epoch  862 Sharpe:  tensor(1.7317)
# Epoch  863 Sharpe:  tensor(1.7317)
# Epoch  864 Sharpe:  tensor(1.7317)
# Epoch  865 Sharpe:  tensor(1.7317)
# Epoch  866 Sharpe:  tensor(1.7317)
# Epoch  867 Sharpe:  tensor(1.7317)
# Epoch  868 Sharpe:  tensor(1.7317)
# Epoch  869 Sharpe:  tensor(1.7317)
# Epoch  870 Sharpe:  tensor(1.7317)
# Epoch  871 Sharpe:  tensor(1.7318)
# Epoch  872 Sharpe:  tensor(1.7318)
# Epoch  873 Sharpe:  tensor(1.7318)
# Epoch  874 Sharpe:  tensor(1.7318)
# Epoch  875 Sharpe:  tensor(1.7318)
# Epoch  876 Sharpe:  tensor(1.7318)
# Epoch  877 Sharpe:  tensor(1.7318)
# Epoch  878 Sharpe:  tensor(1.7318)
# Epoch  879 Sharpe:  tensor(1.7318)
# Epoch  880 Sharpe:  tensor(1.7318)
# Epoch  881 Sharpe:  tensor(1.7318)
# Epoch  882 Sharpe:  tensor(1.7318)
# Epoch  883 Sharpe:  tensor(1.7318)
# Epoch  884 Sharpe:  tensor(1.7318)
# Epoch  885 Sharpe:  tensor(1.7318)
# Epoch  886 Sharpe:  tensor(1.7318)
# Epoch  887 Sharpe:  tensor(1.7318)
# Epoch  888 Sharpe:  tensor(1.7318)
# Epoch  889 Sharpe:  tensor(1.7318)
# Epoch  890 Sharpe:  tensor(1.7318)
# Epoch  891 Sharpe:  tensor(1.7318)
# Epoch  892 Sharpe:  tensor(1.7318)
# Epoch  893 Sharpe:  tensor(1.7318)
# Epoch  894 Sharpe:  tensor(1.7318)
# Epoch  895 Sharpe:  tensor(1.7318)
# Epoch  896 Sharpe:  tensor(1.7318)
# Epoch  897 Sharpe:  tensor(1.7318)
# Epoch  898 Sharpe:  tensor(1.7319)
# Epoch  899 Sharpe:  tensor(1.7319)
# Epoch  900 Sharpe:  tensor(1.7319)
# Epoch  901 Sharpe:  tensor(1.7319)
# Epoch  902 Sharpe:  tensor(1.7307)
# Epoch  903 Sharpe:  tensor(1.7307)
# Epoch  904 Sharpe:  tensor(1.7307)
# Epoch  905 Sharpe:  tensor(1.7307)
# Epoch  906 Sharpe:  tensor(1.7307)
# Epoch  907 Sharpe:  tensor(1.7308)
# Epoch  908 Sharpe:  tensor(1.7308)
# Epoch  909 Sharpe:  tensor(1.7308)
# Epoch  910 Sharpe:  tensor(1.7308)
# Epoch  911 Sharpe:  tensor(1.7308)
# Epoch  912 Sharpe:  tensor(1.7308)
# Epoch  913 Sharpe:  tensor(1.7308)
# Epoch  914 Sharpe:  tensor(1.7308)
# Epoch  915 Sharpe:  tensor(1.7308)
# Epoch  916 Sharpe:  tensor(1.7308)
# Epoch  917 Sharpe:  tensor(1.7308)
# Epoch  918 Sharpe:  tensor(1.7308)
# Epoch  919 Sharpe:  tensor(1.7308)
# Epoch  920 Sharpe:  tensor(1.7308)
# Epoch  921 Sharpe:  tensor(1.7308)
# Epoch  922 Sharpe:  tensor(1.7308)
# Epoch  923 Sharpe:  tensor(1.7308)
# Epoch  924 Sharpe:  tensor(1.7308)
# Epoch  925 Sharpe:  tensor(1.7308)
# Epoch  926 Sharpe:  tensor(1.7308)
# Epoch  927 Sharpe:  tensor(1.7308)
# Epoch  928 Sharpe:  tensor(1.7308)
# Epoch  929 Sharpe:  tensor(1.7308)
# Epoch  930 Sharpe:  tensor(1.7308)
# Epoch  931 Sharpe:  tensor(1.7308)
# Epoch  932 Sharpe:  tensor(1.7308)
# Epoch  933 Sharpe:  tensor(1.7308)
# Epoch  934 Sharpe:  tensor(1.7308)
# Epoch  935 Sharpe:  tensor(1.7308)
# Epoch  936 Sharpe:  tensor(1.7308)
# Epoch  937 Sharpe:  tensor(1.7309)
# Epoch  938 Sharpe:  tensor(1.7309)
# Epoch  939 Sharpe:  tensor(1.7309)
# Epoch  940 Sharpe:  tensor(1.7309)
# Epoch  941 Sharpe:  tensor(1.7309)
# Epoch  942 Sharpe:  tensor(1.7309)
# Epoch  943 Sharpe:  tensor(1.7309)
# Epoch  944 Sharpe:  tensor(1.7309)
# Epoch  945 Sharpe:  tensor(1.7309)
# Epoch  946 Sharpe:  tensor(1.7309)
# Epoch  947 Sharpe:  tensor(1.7309)
# Epoch  948 Sharpe:  tensor(1.7309)
# Epoch  949 Sharpe:  tensor(1.7309)
# Epoch  950 Sharpe:  tensor(1.7309)
# Epoch  951 Sharpe:  tensor(1.7309)
# Epoch  952 Sharpe:  tensor(1.7309)
# Epoch  953 Sharpe:  tensor(1.7309)
# Epoch  954 Sharpe:  tensor(1.7309)
# Epoch  955 Sharpe:  tensor(1.7309)
# Epoch  956 Sharpe:  tensor(1.7309)
# Epoch  957 Sharpe:  tensor(1.7309)
# Epoch  958 Sharpe:  tensor(1.7309)
# Epoch  959 Sharpe:  tensor(1.7309)
# Epoch  960 Sharpe:  tensor(1.7309)
# Epoch  961 Sharpe:  tensor(1.7309)
# Epoch  962 Sharpe:  tensor(1.7309)
# Epoch  963 Sharpe:  tensor(1.7309)
# Epoch  964 Sharpe:  tensor(1.7309)
# Epoch  965 Sharpe:  tensor(1.7309)
# Epoch  966 Sharpe:  tensor(1.7309)
# Epoch  967 Sharpe:  tensor(1.7309)
# Epoch  968 Sharpe:  tensor(1.7309)
# Epoch  969 Sharpe:  tensor(1.7309)
# Epoch  970 Sharpe:  tensor(1.7309)
# Epoch  971 Sharpe:  tensor(1.7309)
# Epoch  972 Sharpe:  tensor(1.7310)
# Epoch  973 Sharpe:  tensor(1.7310)
# Epoch  974 Sharpe:  tensor(1.7310)
# Epoch  975 Sharpe:  tensor(1.7310)
# Epoch  976 Sharpe:  tensor(1.7310)
# Epoch  977 Sharpe:  tensor(1.7310)
# Epoch  978 Sharpe:  tensor(1.7310)
# Epoch  979 Sharpe:  tensor(1.7310)
# Epoch  980 Sharpe:  tensor(1.7310)
# Epoch  981 Sharpe:  tensor(1.7310)
# Epoch  982 Sharpe:  tensor(1.7310)
# Epoch  983 Sharpe:  tensor(1.7310)
# Epoch  984 Sharpe:  tensor(1.7310)
# Epoch  985 Sharpe:  tensor(1.7310)
# Epoch  986 Sharpe:  tensor(1.7310)
# Epoch  987 Sharpe:  tensor(1.7310)
# Epoch  988 Sharpe:  tensor(1.7310)
# Epoch  989 Sharpe:  tensor(1.7310)
# Epoch  990 Sharpe:  tensor(1.7310)
# Epoch  991 Sharpe:  tensor(1.7310)
# Epoch  992 Sharpe:  tensor(1.7310)
# Epoch  993 Sharpe:  tensor(1.7310)
# Epoch  994 Sharpe:  tensor(1.7310)
# Epoch  995 Sharpe:  tensor(1.7310)
# Epoch  996 Sharpe:  tensor(1.7310)
# Epoch  997 Sharpe:  tensor(1.7310)
# Epoch  998 Sharpe:  tensor(1.7310)
# Epoch  999 Sharpe:  tensor(1.7310)
# Cum_return_train tensor(57283.1875, grad_fn=<SelectBackward>)

# %% [markdown]
# ## 4. Visualization

# %%
plt.rcParams['figure.figsize'] = [7, 3]
# plt.title("sharp's ratio optimization LSTMRL")
plt.plot(rewards)
# plt.ylim((-0.5,0.5))
# plt.legend(['sharp\'s ratio(LRL):M=25,layer=3'],loc='upper left')
plt.savefig("SRLRL25-1.png", dpi=300)
plt.show()

plt.rcParams['figure.figsize'] = [15, 8]
f, axes = plt.subplots(3, 1, sharex=True)
# plt.suptitle("BTC LSTMRL Train", fontsize=16)
axes[0].set_ylabel("Prices")
axes[0].plot(prices[M:M+T])
axes[1].set_ylabel("Strategy Returns")
axes[1].plot(Cum_returns.detach().numpy())
axes[2].set_ylabel("Ft")
axes[2].bar(list(range(len(Cum_returns))), Ft[:-1].detach().numpy())
# plt.legend(['Train(LRL):M=25,layer=3'],loc='upper left')
plt.savefig("TrainLRL25-1.png", dpi=300)
plt.show()

# %%
# data:M+T:M+T+N+1
prices_test = np.array(raw_prices[1])[OFFSET+M+T:]
# OFFSET = 0 #数据起始点
# M = 25  #输入网络的历史窗口的大小，用于在每个时间步更新权重的历史大小
# T = 2000 #交易者输入的时间序列长度
# N = 600  #验证集大小
# # prices_test = prices_test[OFFSET+M+T:]
# prices_test = np.array(raw_prices[1])[OFFSET+M+T:]
# print(prices[OFFSET+M+T:])
asset_returns_test = asset_returns[:M+N+1]
scaler = StandardScaler()
normalized_asset_returns_test = torch.tensor(scaler.fit_transform(asset_returns_test[:M+N+1][:, None])[:, 0]).to(torch.float32)
# normalized_asset_returns_test = normalized_asset_returns[M+T:T+M+N+1]
# print(asset_returns_test,normalized_asset_returns_test)

rewards_test = []
Ft_test = torch.zeros(N).to(normalized_asset_returns_test.device)
for i in range(1, N):
    data_test = normalized_asset_returns_test[i-1:i+M-1]
    input_test = data_test.view(1,M,1).to(device)
    Ft_test[i] = model(input_test)
    returns_test = miu * (Ft_test[:N-1] * asset_returns_test[M:M+N-1]) - (delta * torch.abs(Ft_test[1:] - Ft_test[:N-1]))
    expected_return_test = torch.mean(returns_test, dim=-1)
    std_return_test = torch.std(returns_test, dim=-1)
    sharpe_test = expected_return_test / (torch.sqrt(std_return_test) + eps)
    rewards_test.append(sharpe_test.detach().cpu())
Cum_return_tests = returns_test.cumsum(dim=-1)# data:M+T:M+T+N+1
print('Cum_return_test',Cum_return_tests[-1])
# Out:
# Cum_return_test tensor(-92.4301, grad_fn=<SelectBackward>)

# %%
plt.rcParams['figure.figsize'] = [15, 8]
f, axes = plt.subplots(4, 1, sharex=True)
axes[0].set_ylabel("Prices")
axes[0].plot(prices_test[M:M+N+1])
axes[1].set_ylabel("Sharpe ratio")
axes[1].plot(rewards_test)
axes[2].set_ylabel("Strategy Returns")
axes[2].plot(Cum_return_tests.detach().numpy())
axes[3].set_ylabel("Ft")
axes[3].bar(list(range(len(Cum_return_tests))), Ft_test[:-1].detach().numpy())
plt.savefig("TestLRL25-1.png", dpi=300)
plt.show()
