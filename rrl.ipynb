# %% [markdown]
# # RL Trading based on RNN

# %%
import torch
import torch.nn as nn
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random

# %%
# def setup_seed(seed):
#     torch.manual_seed(seed)
#     torch.cuda.manual_seed_all(seed)
#     np.random.seed(seed)
#     random.seed(seed)
#     torch.backends.cudnn.deterministic = True
# # 设置随机数种子
# setup_seed(20)

# %% [markdown]
# ## 1. Loading data and data preprocessing

# %%
raw_prices = pd.read_csv("BTC.csv", header=None)
prices = np.array(raw_prices[1])
OFFSET = 200 #数据起始点
M = 20  #输入网络的历史窗口的大小，用于在每个时间步更新权重的历史大小,r的系数个数
T = 2000 #交易者输入的时间序列长度
N = 600  #验证集大小
prices = prices[OFFSET:OFFSET+M+T+N+1]
# asset_returns = torch.tensor(np.log(prices[1:]) - np.log(prices[:-1])).to(torch.float32)
asset_returns = torch.tensor(prices[1:] - prices[:-1]).to(torch.float32)
print('asset_returns',asset_returns)
scaler = StandardScaler()
normalized_asset_returns = torch.tensor(scaler.fit_transform(asset_returns[:M+T][:, None])[:, 0]).to(torch.float32)
# Out:
# asset_returns tensor([-1.6900e+00, -6.6000e-01, -2.1400e+00,  ..., -1.0181e+03,
#         -4.4164e+03, -2.1501e+03])

# %% [markdown]
# ## 2. Create NN model

# %%
class RRL(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim):
        super(RRL, self).__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers

        self.rnn = nn.RNN(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).requires_grad_().cuda()
        out, (hn) = self.rnn(x, (h0.detach()))
        out = self.fc(out[:, -1, :])
        return torch.tanh(out)

# %%
input_dim = 1
hidden_dim = 64
num_layers = 3
output_dim = 1
use_gpu = torch.cuda.is_available()
device = torch.device("cuda" if use_gpu else "cpu")
model = RRL(input_dim=input_dim, hidden_dim=hidden_dim, output_dim=output_dim, num_layers=num_layers).to(device)
print(model)
# Out:
# RRL(
#   (rnn): RNN(1, 64, num_layers=3, batch_first=True)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
# )

# %% [markdown]
# ## 3. Train the model

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
rewards = []
max_iter = 1000
miu = 1
delta = 0.04
eps = 1e-6

# %%
for epoch in range(max_iter):
    optimizer.zero_grad()
    Ft = torch.zeros(T).to(normalized_asset_returns.device)
    for i in range(1, T):
        data = normalized_asset_returns[i-1:i+M-1]
        input = data.view(1,M,1).to(device)
        Ft[i] = model(input)
    returns = miu * (Ft[:T-1] * asset_returns[M:M+T-1]) - (delta * torch.abs(Ft[1:] - Ft[:T-1]))
    expected_return = torch.mean(returns, dim=-1)
    std_return = torch.std(returns, dim=-1)
    sharpe = expected_return / (torch.sqrt(std_return) + eps)
    (-1 * sharpe).backward()
    optimizer.step()
    rewards.append(sharpe.detach().cpu())
    Cum_return_train = returns.cumsum(dim=-1)
    print("Epoch ", epoch, "Sharpe: ", sharpe.detach().cpu())
# print('Cum_return_train',Cum_returns[-1])
# Out:
# Epoch  0 Sharpe:  tensor(-0.0943)
# Epoch  1 Sharpe:  tensor(0.0853)
# Epoch  2 Sharpe:  tensor(0.2348)
# Epoch  3 Sharpe:  tensor(0.3120)
# Epoch  4 Sharpe:  tensor(0.3711)
# Epoch  5 Sharpe:  tensor(0.4260)
# Epoch  6 Sharpe:  tensor(0.4800)
# Epoch  7 Sharpe:  tensor(0.5331)
# Epoch  8 Sharpe:  tensor(0.5850)
# Epoch  9 Sharpe:  tensor(0.6364)
# Epoch  10 Sharpe:  tensor(0.6897)
# Epoch  11 Sharpe:  tensor(0.7480)
# Epoch  12 Sharpe:  tensor(0.8132)
# Epoch  13 Sharpe:  tensor(0.8823)
# Epoch  14 Sharpe:  tensor(0.9471)
# Epoch  15 Sharpe:  tensor(0.9992)
# Epoch  16 Sharpe:  tensor(1.0374)
# Epoch  17 Sharpe:  tensor(1.0664)
# Epoch  18 Sharpe:  tensor(1.0923)
# Epoch  19 Sharpe:  tensor(1.1186)
# Epoch  20 Sharpe:  tensor(1.1457)
# Epoch  21 Sharpe:  tensor(1.1718)
# Epoch  22 Sharpe:  tensor(1.1951)
# Epoch  23 Sharpe:  tensor(1.2147)
# Epoch  24 Sharpe:  tensor(1.2315)
# Epoch  25 Sharpe:  tensor(1.2469)
# Epoch  26 Sharpe:  tensor(1.2622)
# Epoch  27 Sharpe:  tensor(1.2786)
# Epoch  28 Sharpe:  tensor(1.2957)
# Epoch  29 Sharpe:  tensor(1.3132)
# Epoch  30 Sharpe:  tensor(1.3324)
# Epoch  31 Sharpe:  tensor(1.3515)
# Epoch  32 Sharpe:  tensor(1.3697)
# Epoch  33 Sharpe:  tensor(1.3872)
# Epoch  34 Sharpe:  tensor(1.4030)
# Epoch  35 Sharpe:  tensor(1.4196)
# Epoch  36 Sharpe:  tensor(1.4366)
# Epoch  37 Sharpe:  tensor(1.4539)
# Epoch  38 Sharpe:  tensor(1.4702)
# Epoch  39 Sharpe:  tensor(1.4853)
# Epoch  40 Sharpe:  tensor(1.4998)
# Epoch  41 Sharpe:  tensor(1.5139)
# Epoch  42 Sharpe:  tensor(1.5273)
# Epoch  43 Sharpe:  tensor(1.5404)
# Epoch  44 Sharpe:  tensor(1.5536)
# Epoch  45 Sharpe:  tensor(1.5678)
# Epoch  46 Sharpe:  tensor(1.5834)
# Epoch  47 Sharpe:  tensor(1.6024)
# Epoch  48 Sharpe:  tensor(1.6314)
# Epoch  49 Sharpe:  tensor(1.6375)
# Epoch  50 Sharpe:  tensor(1.6267)
# Epoch  51 Sharpe:  tensor(1.6395)
# Epoch  52 Sharpe:  tensor(1.7425)
# Epoch  53 Sharpe:  tensor(1.7117)
# Epoch  54 Sharpe:  tensor(1.7134)
# Epoch  55 Sharpe:  tensor(1.7395)
# Epoch  56 Sharpe:  tensor(1.7154)
# Epoch  57 Sharpe:  tensor(1.7942)
# Epoch  58 Sharpe:  tensor(1.7410)
# Epoch  59 Sharpe:  tensor(1.8009)
# Epoch  60 Sharpe:  tensor(1.7866)
# Epoch  61 Sharpe:  tensor(1.8007)
# Epoch  62 Sharpe:  tensor(1.8237)
# Epoch  63 Sharpe:  tensor(1.8277)
# Epoch  64 Sharpe:  tensor(1.8290)
# Epoch  65 Sharpe:  tensor(1.8588)
# Epoch  66 Sharpe:  tensor(1.8570)
# Epoch  67 Sharpe:  tensor(1.8729)
# Epoch  68 Sharpe:  tensor(1.8564)
# Epoch  69 Sharpe:  tensor(1.8819)
# Epoch  70 Sharpe:  tensor(1.8925)
# Epoch  71 Sharpe:  tensor(1.8955)
# Epoch  72 Sharpe:  tensor(1.9204)
# Epoch  73 Sharpe:  tensor(1.9295)
# Epoch  74 Sharpe:  tensor(1.9336)
# Epoch  75 Sharpe:  tensor(1.9391)
# Epoch  76 Sharpe:  tensor(1.9469)
# Epoch  77 Sharpe:  tensor(1.9598)
# Epoch  78 Sharpe:  tensor(1.9753)
# Epoch  79 Sharpe:  tensor(1.9749)
# Epoch  80 Sharpe:  tensor(1.9800)
# Epoch  81 Sharpe:  tensor(1.9891)
# Epoch  82 Sharpe:  tensor(2.0033)
# Epoch  83 Sharpe:  tensor(2.0067)
# Epoch  84 Sharpe:  tensor(2.0161)
# Epoch  85 Sharpe:  tensor(2.0184)
# Epoch  86 Sharpe:  tensor(2.0250)
# Epoch  87 Sharpe:  tensor(2.0138)
# Epoch  88 Sharpe:  tensor(2.0096)
# Epoch  89 Sharpe:  tensor(2.0356)
# Epoch  90 Sharpe:  tensor(2.0405)
# Epoch  91 Sharpe:  tensor(2.0568)
# Epoch  92 Sharpe:  tensor(2.0652)
# Epoch  93 Sharpe:  tensor(2.0623)
# Epoch  94 Sharpe:  tensor(2.0176)
# Epoch  95 Sharpe:  tensor(2.0697)
# Epoch  96 Sharpe:  tensor(2.0186)
# Epoch  97 Sharpe:  tensor(1.9017)
# Epoch  98 Sharpe:  tensor(1.9709)
# Epoch  99 Sharpe:  tensor(2.0202)
# Epoch  100 Sharpe:  tensor(1.9997)
# Epoch  101 Sharpe:  tensor(1.9269)
# Epoch  102 Sharpe:  tensor(1.8877)
# Epoch  103 Sharpe:  tensor(1.9231)
# Epoch  104 Sharpe:  tensor(1.9855)
# Epoch  105 Sharpe:  tensor(2.0041)
# Epoch  106 Sharpe:  tensor(2.0241)
# Epoch  107 Sharpe:  tensor(1.9603)
# Epoch  108 Sharpe:  tensor(1.9274)
# Epoch  109 Sharpe:  tensor(1.9608)
# Epoch  110 Sharpe:  tensor(1.9777)
# Epoch  111 Sharpe:  tensor(2.0040)
# Epoch  112 Sharpe:  tensor(2.0517)
# Epoch  113 Sharpe:  tensor(1.9992)
# Epoch  114 Sharpe:  tensor(1.9997)
# Epoch  115 Sharpe:  tensor(1.9743)
# Epoch  116 Sharpe:  tensor(1.9776)
# Epoch  117 Sharpe:  tensor(2.0120)
# Epoch  118 Sharpe:  tensor(2.0533)
# Epoch  119 Sharpe:  tensor(2.0467)
# Epoch  120 Sharpe:  tensor(2.0032)
# Epoch  121 Sharpe:  tensor(1.9439)
# Epoch  122 Sharpe:  tensor(2.0190)
# Epoch  123 Sharpe:  tensor(2.0719)
# Epoch  124 Sharpe:  tensor(2.0143)
# Epoch  125 Sharpe:  tensor(2.0578)
# Epoch  126 Sharpe:  tensor(2.0811)
# Epoch  127 Sharpe:  tensor(2.0581)
# Epoch  128 Sharpe:  tensor(2.0671)
# Epoch  129 Sharpe:  tensor(2.0784)
# Epoch  130 Sharpe:  tensor(2.0956)
# Epoch  131 Sharpe:  tensor(2.1010)
# Epoch  132 Sharpe:  tensor(2.0842)
# Epoch  133 Sharpe:  tensor(2.1092)
# Epoch  134 Sharpe:  tensor(2.0984)
# Epoch  135 Sharpe:  tensor(2.0902)
# Epoch  136 Sharpe:  tensor(2.1157)
# Epoch  137 Sharpe:  tensor(2.1041)
# Epoch  138 Sharpe:  tensor(2.1010)
# Epoch  139 Sharpe:  tensor(2.1262)
# Epoch  140 Sharpe:  tensor(2.1172)
# Epoch  141 Sharpe:  tensor(2.1157)
# Epoch  142 Sharpe:  tensor(2.1333)
# Epoch  143 Sharpe:  tensor(2.1212)
# Epoch  144 Sharpe:  tensor(2.1355)
# Epoch  145 Sharpe:  tensor(2.1317)
# Epoch  146 Sharpe:  tensor(2.1417)
# Epoch  147 Sharpe:  tensor(2.1404)
# Epoch  148 Sharpe:  tensor(2.1495)
# Epoch  149 Sharpe:  tensor(2.1466)
# Epoch  150 Sharpe:  tensor(2.1486)
# Epoch  151 Sharpe:  tensor(2.1557)
# Epoch  152 Sharpe:  tensor(2.1493)
# Epoch  153 Sharpe:  tensor(2.1566)
# Epoch  154 Sharpe:  tensor(2.1511)
# Epoch  155 Sharpe:  tensor(2.1597)
# Epoch  156 Sharpe:  tensor(2.1591)
# Epoch  157 Sharpe:  tensor(2.1609)
# Epoch  158 Sharpe:  tensor(2.1640)
# Epoch  159 Sharpe:  tensor(2.1631)
# Epoch  160 Sharpe:  tensor(2.1642)
# Epoch  161 Sharpe:  tensor(2.1689)
# Epoch  162 Sharpe:  tensor(2.1670)
# Epoch  163 Sharpe:  tensor(2.1721)
# Epoch  164 Sharpe:  tensor(2.1715)
# Epoch  165 Sharpe:  tensor(2.1747)
# Epoch  166 Sharpe:  tensor(2.1740)
# Epoch  167 Sharpe:  tensor(2.1774)
# Epoch  168 Sharpe:  tensor(2.1786)
# Epoch  169 Sharpe:  tensor(2.1800)
# Epoch  170 Sharpe:  tensor(2.1837)
# Epoch  171 Sharpe:  tensor(2.1853)
# Epoch  172 Sharpe:  tensor(2.1852)
# Epoch  173 Sharpe:  tensor(2.1862)
# Epoch  174 Sharpe:  tensor(2.1898)
# Epoch  175 Sharpe:  tensor(2.1925)
# Epoch  176 Sharpe:  tensor(2.1942)
# Epoch  177 Sharpe:  tensor(2.1957)
# Epoch  178 Sharpe:  tensor(2.1967)
# Epoch  179 Sharpe:  tensor(2.1966)
# Epoch  180 Sharpe:  tensor(2.1904)
# Epoch  181 Sharpe:  tensor(2.1862)
# Epoch  182 Sharpe:  tensor(2.1516)
# Epoch  183 Sharpe:  tensor(2.1739)
# Epoch  184 Sharpe:  tensor(2.1808)
# Epoch  185 Sharpe:  tensor(2.1938)
# Epoch  186 Sharpe:  tensor(2.1837)
# Epoch  187 Sharpe:  tensor(2.1967)
# Epoch  188 Sharpe:  tensor(2.1945)
# Epoch  189 Sharpe:  tensor(2.2039)
# Epoch  190 Sharpe:  tensor(2.2026)
# Epoch  191 Sharpe:  tensor(2.2066)
# Epoch  192 Sharpe:  tensor(2.1975)
# Epoch  193 Sharpe:  tensor(2.2105)
# Epoch  194 Sharpe:  tensor(2.2099)
# Epoch  195 Sharpe:  tensor(2.2098)
# Epoch  196 Sharpe:  tensor(2.2097)
# Epoch  197 Sharpe:  tensor(2.2128)
# Epoch  198 Sharpe:  tensor(2.2143)
# Epoch  199 Sharpe:  tensor(2.2131)
# Epoch  200 Sharpe:  tensor(2.2176)
# Epoch  201 Sharpe:  tensor(2.2022)
# Epoch  202 Sharpe:  tensor(2.1089)
# Epoch  203 Sharpe:  tensor(1.9805)
# Epoch  204 Sharpe:  tensor(1.9724)
# Epoch  205 Sharpe:  tensor(2.1737)
# Epoch  206 Sharpe:  tensor(1.9024)
# Epoch  207 Sharpe:  tensor(1.9622)
# Epoch  208 Sharpe:  tensor(2.1120)
# Epoch  209 Sharpe:  tensor(1.9102)
# Epoch  210 Sharpe:  tensor(1.9381)
# Epoch  211 Sharpe:  tensor(2.0736)
# Epoch  212 Sharpe:  tensor(2.0576)
# Epoch  213 Sharpe:  tensor(2.0646)
# Epoch  214 Sharpe:  tensor(2.1299)
# Epoch  215 Sharpe:  tensor(2.1356)
# Epoch  216 Sharpe:  tensor(2.1270)
# Epoch  217 Sharpe:  tensor(2.1396)
# Epoch  218 Sharpe:  tensor(2.1410)
# Epoch  219 Sharpe:  tensor(2.1380)
# Epoch  220 Sharpe:  tensor(2.1694)
# Epoch  221 Sharpe:  tensor(2.1860)
# Epoch  222 Sharpe:  tensor(2.1980)
# Epoch  223 Sharpe:  tensor(2.2018)
# Epoch  224 Sharpe:  tensor(2.1898)
# Epoch  225 Sharpe:  tensor(2.2001)
# Epoch  226 Sharpe:  tensor(2.1888)
# Epoch  227 Sharpe:  tensor(2.1858)
# Epoch  228 Sharpe:  tensor(2.1866)
# Epoch  229 Sharpe:  tensor(2.1911)
# Epoch  230 Sharpe:  tensor(2.2111)
# Epoch  231 Sharpe:  tensor(2.2086)
# Epoch  232 Sharpe:  tensor(2.1983)
# Epoch  233 Sharpe:  tensor(2.2224)
# Epoch  234 Sharpe:  tensor(2.2154)
# Epoch  235 Sharpe:  tensor(2.2271)
# Epoch  236 Sharpe:  tensor(2.2215)
# Epoch  237 Sharpe:  tensor(2.2199)
# Epoch  238 Sharpe:  tensor(2.2355)
# Epoch  239 Sharpe:  tensor(2.2253)
# Epoch  240 Sharpe:  tensor(2.2351)
# Epoch  241 Sharpe:  tensor(2.2262)
# Epoch  242 Sharpe:  tensor(2.2283)
# Epoch  243 Sharpe:  tensor(2.2265)
# Epoch  244 Sharpe:  tensor(2.2035)
# Epoch  245 Sharpe:  tensor(2.2313)
# Epoch  246 Sharpe:  tensor(2.2396)
# Epoch  247 Sharpe:  tensor(2.2319)
# Epoch  248 Sharpe:  tensor(2.2504)
# Epoch  249 Sharpe:  tensor(2.2076)
# Epoch  250 Sharpe:  tensor(2.2151)
# Epoch  251 Sharpe:  tensor(2.2431)
# Epoch  252 Sharpe:  tensor(2.1991)
# Epoch  253 Sharpe:  tensor(2.2279)
# Epoch  254 Sharpe:  tensor(2.1873)
# Epoch  255 Sharpe:  tensor(2.2260)
# Epoch  256 Sharpe:  tensor(2.1883)
# Epoch  257 Sharpe:  tensor(2.1323)
# Epoch  258 Sharpe:  tensor(2.2377)
# Epoch  259 Sharpe:  tensor(2.1155)
# Epoch  260 Sharpe:  tensor(2.2367)
# Epoch  261 Sharpe:  tensor(2.1730)
# Epoch  262 Sharpe:  tensor(2.2347)
# Epoch  263 Sharpe:  tensor(2.1874)
# Epoch  264 Sharpe:  tensor(2.2012)
# Epoch  265 Sharpe:  tensor(2.2317)
# Epoch  266 Sharpe:  tensor(2.2008)
# Epoch  267 Sharpe:  tensor(2.2424)
# Epoch  268 Sharpe:  tensor(2.2034)
# Epoch  269 Sharpe:  tensor(2.2266)
# Epoch  270 Sharpe:  tensor(2.2320)
# Epoch  271 Sharpe:  tensor(2.2122)
# Epoch  272 Sharpe:  tensor(2.2436)
# Epoch  273 Sharpe:  tensor(2.2331)
# Epoch  274 Sharpe:  tensor(2.2447)
# Epoch  275 Sharpe:  tensor(2.2474)
# Epoch  276 Sharpe:  tensor(2.2094)
# Epoch  277 Sharpe:  tensor(2.2175)
# Epoch  278 Sharpe:  tensor(2.2099)
# Epoch  279 Sharpe:  tensor(2.2367)
# Epoch  280 Sharpe:  tensor(2.1261)
# Epoch  281 Sharpe:  tensor(2.2267)
# Epoch  282 Sharpe:  tensor(2.0463)
# Epoch  283 Sharpe:  tensor(2.1516)
# Epoch  284 Sharpe:  tensor(2.1834)
# Epoch  285 Sharpe:  tensor(2.1718)
# Epoch  286 Sharpe:  tensor(2.0390)
# Epoch  287 Sharpe:  tensor(2.1699)
# Epoch  288 Sharpe:  tensor(2.0045)
# Epoch  289 Sharpe:  tensor(2.1343)
# Epoch  290 Sharpe:  tensor(2.1468)
# Epoch  291 Sharpe:  tensor(2.1987)
# Epoch  292 Sharpe:  tensor(1.9912)
# Epoch  293 Sharpe:  tensor(2.1968)
# Epoch  294 Sharpe:  tensor(2.2112)
# Epoch  295 Sharpe:  tensor(2.1979)
# Epoch  296 Sharpe:  tensor(2.1669)
# Epoch  297 Sharpe:  tensor(2.2141)
# Epoch  298 Sharpe:  tensor(2.2409)
# Epoch  299 Sharpe:  tensor(2.2334)
# Epoch  300 Sharpe:  tensor(2.2258)
# Epoch  301 Sharpe:  tensor(2.2355)
# Epoch  302 Sharpe:  tensor(2.2515)
# Epoch  303 Sharpe:  tensor(2.2520)
# Epoch  304 Sharpe:  tensor(2.2491)
# Epoch  305 Sharpe:  tensor(2.2524)
# Epoch  306 Sharpe:  tensor(2.2602)
# Epoch  307 Sharpe:  tensor(2.2634)
# Epoch  308 Sharpe:  tensor(2.2577)
# Epoch  309 Sharpe:  tensor(2.2628)
# Epoch  310 Sharpe:  tensor(2.2743)
# Epoch  311 Sharpe:  tensor(2.2754)
# Epoch  312 Sharpe:  tensor(2.2804)
# Epoch  313 Sharpe:  tensor(2.2835)
# Epoch  314 Sharpe:  tensor(2.2898)
# Epoch  315 Sharpe:  tensor(2.2870)
# Epoch  316 Sharpe:  tensor(2.2923)
# Epoch  317 Sharpe:  tensor(2.2948)
# Epoch  318 Sharpe:  tensor(2.2989)
# Epoch  319 Sharpe:  tensor(2.3032)
# Epoch  320 Sharpe:  tensor(2.3017)
# Epoch  321 Sharpe:  tensor(2.3061)
# Epoch  322 Sharpe:  tensor(2.3051)
# Epoch  323 Sharpe:  tensor(2.3056)
# Epoch  324 Sharpe:  tensor(2.3082)
# Epoch  325 Sharpe:  tensor(2.3081)
# Epoch  326 Sharpe:  tensor(2.3179)
# Epoch  327 Sharpe:  tensor(2.3156)
# Epoch  328 Sharpe:  tensor(2.3024)
# Epoch  329 Sharpe:  tensor(2.3228)
# Epoch  330 Sharpe:  tensor(2.3275)
# Epoch  331 Sharpe:  tensor(2.3151)
# Epoch  332 Sharpe:  tensor(2.3068)
# Epoch  333 Sharpe:  tensor(2.3236)
# Epoch  334 Sharpe:  tensor(2.3362)
# Epoch  335 Sharpe:  tensor(2.3198)
# Epoch  336 Sharpe:  tensor(2.3421)
# Epoch  337 Sharpe:  tensor(2.3326)
# Epoch  338 Sharpe:  tensor(2.3399)
# Epoch  339 Sharpe:  tensor(2.3339)
# Epoch  340 Sharpe:  tensor(2.3409)
# Epoch  341 Sharpe:  tensor(2.3406)
# Epoch  342 Sharpe:  tensor(2.3378)
# Epoch  343 Sharpe:  tensor(2.3436)
# Epoch  344 Sharpe:  tensor(2.3407)
# Epoch  345 Sharpe:  tensor(2.3507)
# Epoch  346 Sharpe:  tensor(2.3461)
# Epoch  347 Sharpe:  tensor(2.3499)
# Epoch  348 Sharpe:  tensor(2.3499)
# Epoch  349 Sharpe:  tensor(2.3505)
# Epoch  350 Sharpe:  tensor(2.3492)
# Epoch  351 Sharpe:  tensor(2.3519)
# Epoch  352 Sharpe:  tensor(2.3511)
# Epoch  353 Sharpe:  tensor(2.3515)
# Epoch  354 Sharpe:  tensor(2.3530)
# Epoch  355 Sharpe:  tensor(2.3529)
# Epoch  356 Sharpe:  tensor(2.3536)
# Epoch  357 Sharpe:  tensor(2.3535)
# Epoch  358 Sharpe:  tensor(2.3545)
# Epoch  359 Sharpe:  tensor(2.3544)
# Epoch  360 Sharpe:  tensor(2.3542)
# Epoch  361 Sharpe:  tensor(2.3550)
# Epoch  362 Sharpe:  tensor(2.3550)
# Epoch  363 Sharpe:  tensor(2.3551)
# Epoch  364 Sharpe:  tensor(2.3553)
# Epoch  365 Sharpe:  tensor(2.3553)
# Epoch  366 Sharpe:  tensor(2.3558)
# Epoch  367 Sharpe:  tensor(2.3557)
# Epoch  368 Sharpe:  tensor(2.3557)
# Epoch  369 Sharpe:  tensor(2.3561)
# Epoch  370 Sharpe:  tensor(2.3562)
# Epoch  371 Sharpe:  tensor(2.3563)
# Epoch  372 Sharpe:  tensor(2.3566)
# Epoch  373 Sharpe:  tensor(2.3567)
# Epoch  374 Sharpe:  tensor(2.3569)
# Epoch  375 Sharpe:  tensor(2.3571)
# Epoch  376 Sharpe:  tensor(2.3571)
# Epoch  377 Sharpe:  tensor(2.3573)
# Epoch  378 Sharpe:  tensor(2.3575)
# Epoch  379 Sharpe:  tensor(2.3575)
# Epoch  380 Sharpe:  tensor(2.3576)
# Epoch  381 Sharpe:  tensor(2.3577)
# Epoch  382 Sharpe:  tensor(2.3578)
# Epoch  383 Sharpe:  tensor(2.3579)
# Epoch  384 Sharpe:  tensor(2.3580)
# Epoch  385 Sharpe:  tensor(2.3580)
# Epoch  386 Sharpe:  tensor(2.3582)
# Epoch  387 Sharpe:  tensor(2.3582)
# Epoch  388 Sharpe:  tensor(2.3583)
# Epoch  389 Sharpe:  tensor(2.3583)
# Epoch  390 Sharpe:  tensor(2.3584)
# Epoch  391 Sharpe:  tensor(2.3585)
# Epoch  392 Sharpe:  tensor(2.3585)
# Epoch  393 Sharpe:  tensor(2.3586)
# Epoch  394 Sharpe:  tensor(2.3586)
# Epoch  395 Sharpe:  tensor(2.3587)
# Epoch  396 Sharpe:  tensor(2.3587)
# Epoch  397 Sharpe:  tensor(2.3588)
# Epoch  398 Sharpe:  tensor(2.3588)
# Epoch  399 Sharpe:  tensor(2.3589)
# Epoch  400 Sharpe:  tensor(2.3589)
# Epoch  401 Sharpe:  tensor(2.3589)
# Epoch  402 Sharpe:  tensor(2.3590)
# Epoch  403 Sharpe:  tensor(2.3590)
# Epoch  404 Sharpe:  tensor(2.3590)
# Epoch  405 Sharpe:  tensor(2.3591)
# Epoch  406 Sharpe:  tensor(2.3591)
# Epoch  407 Sharpe:  tensor(2.3591)
# Epoch  408 Sharpe:  tensor(2.3592)
# Epoch  409 Sharpe:  tensor(2.3592)
# Epoch  410 Sharpe:  tensor(2.3592)
# Epoch  411 Sharpe:  tensor(2.3593)
# Epoch  412 Sharpe:  tensor(2.3593)
# Epoch  413 Sharpe:  tensor(2.3593)
# Epoch  414 Sharpe:  tensor(2.3594)
# Epoch  415 Sharpe:  tensor(2.3594)
# Epoch  416 Sharpe:  tensor(2.3594)
# Epoch  417 Sharpe:  tensor(2.3594)
# Epoch  418 Sharpe:  tensor(2.3595)
# Epoch  419 Sharpe:  tensor(2.3595)
# Epoch  420 Sharpe:  tensor(2.3595)
# Epoch  421 Sharpe:  tensor(2.3595)
# Epoch  422 Sharpe:  tensor(2.3596)
# Epoch  423 Sharpe:  tensor(2.3596)
# Epoch  424 Sharpe:  tensor(2.3596)
# Epoch  425 Sharpe:  tensor(2.3597)
# Epoch  426 Sharpe:  tensor(2.3597)
# Epoch  427 Sharpe:  tensor(2.3597)
# Epoch  428 Sharpe:  tensor(2.3598)
# Epoch  429 Sharpe:  tensor(2.3598)
# Epoch  430 Sharpe:  tensor(2.3598)
# Epoch  431 Sharpe:  tensor(2.3599)
# Epoch  432 Sharpe:  tensor(2.3599)
# Epoch  433 Sharpe:  tensor(2.3600)
# Epoch  434 Sharpe:  tensor(2.3600)
# Epoch  435 Sharpe:  tensor(2.3601)
# Epoch  436 Sharpe:  tensor(2.3602)
# Epoch  437 Sharpe:  tensor(2.3604)
# Epoch  438 Sharpe:  tensor(2.3605)
# Epoch  439 Sharpe:  tensor(2.3608)
# Epoch  440 Sharpe:  tensor(2.3610)
# Epoch  441 Sharpe:  tensor(2.3613)
# Epoch  442 Sharpe:  tensor(2.3615)
# Epoch  443 Sharpe:  tensor(2.3618)
# Epoch  444 Sharpe:  tensor(2.3620)
# Epoch  445 Sharpe:  tensor(2.3622)
# Epoch  446 Sharpe:  tensor(2.3625)
# Epoch  447 Sharpe:  tensor(2.3628)
# Epoch  448 Sharpe:  tensor(2.3631)
# Epoch  449 Sharpe:  tensor(2.3633)
# Epoch  450 Sharpe:  tensor(2.3636)
# Epoch  451 Sharpe:  tensor(2.3638)
# Epoch  452 Sharpe:  tensor(2.3640)
# Epoch  453 Sharpe:  tensor(2.3642)
# Epoch  454 Sharpe:  tensor(2.3644)
# Epoch  455 Sharpe:  tensor(2.3647)
# Epoch  456 Sharpe:  tensor(2.3649)
# Epoch  457 Sharpe:  tensor(2.3650)
# Epoch  458 Sharpe:  tensor(2.3652)
# Epoch  459 Sharpe:  tensor(2.3654)
# Epoch  460 Sharpe:  tensor(2.3655)
# Epoch  461 Sharpe:  tensor(2.3657)
# Epoch  462 Sharpe:  tensor(2.3658)
# Epoch  463 Sharpe:  tensor(2.3660)
# Epoch  464 Sharpe:  tensor(2.3661)
# Epoch  465 Sharpe:  tensor(2.3662)
# Epoch  466 Sharpe:  tensor(2.3663)
# Epoch  467 Sharpe:  tensor(2.3664)
# Epoch  468 Sharpe:  tensor(2.3665)
# Epoch  469 Sharpe:  tensor(2.3665)
# Epoch  470 Sharpe:  tensor(2.3666)
# Epoch  471 Sharpe:  tensor(2.3667)
# Epoch  472 Sharpe:  tensor(2.3668)
# Epoch  473 Sharpe:  tensor(2.3668)
# Epoch  474 Sharpe:  tensor(2.3669)
# Epoch  475 Sharpe:  tensor(2.3670)
# Epoch  476 Sharpe:  tensor(2.3670)
# Epoch  477 Sharpe:  tensor(2.3671)
# Epoch  478 Sharpe:  tensor(2.3671)
# Epoch  479 Sharpe:  tensor(2.3672)
# Epoch  480 Sharpe:  tensor(2.3672)
# Epoch  481 Sharpe:  tensor(2.3673)
# Epoch  482 Sharpe:  tensor(2.3673)
# Epoch  483 Sharpe:  tensor(2.3674)
# Epoch  484 Sharpe:  tensor(2.3674)
# Epoch  485 Sharpe:  tensor(2.3675)
# Epoch  486 Sharpe:  tensor(2.3675)
# Epoch  487 Sharpe:  tensor(2.3675)
# Epoch  488 Sharpe:  tensor(2.3676)
# Epoch  489 Sharpe:  tensor(2.3676)
# Epoch  490 Sharpe:  tensor(2.3676)
# Epoch  491 Sharpe:  tensor(2.3677)
# Epoch  492 Sharpe:  tensor(2.3677)
# Epoch  493 Sharpe:  tensor(2.3677)
# Epoch  494 Sharpe:  tensor(2.3678)
# Epoch  495 Sharpe:  tensor(2.3678)
# Epoch  496 Sharpe:  tensor(2.3678)
# Epoch  497 Sharpe:  tensor(2.3679)
# Epoch  498 Sharpe:  tensor(2.3679)
# Epoch  499 Sharpe:  tensor(2.3679)
# Epoch  500 Sharpe:  tensor(2.3679)
# Epoch  501 Sharpe:  tensor(2.3680)
# Epoch  502 Sharpe:  tensor(2.3680)
# Epoch  503 Sharpe:  tensor(2.3680)
# Epoch  504 Sharpe:  tensor(2.3680)
# Epoch  505 Sharpe:  tensor(2.3681)
# Epoch  506 Sharpe:  tensor(2.3681)
# Epoch  507 Sharpe:  tensor(2.3681)
# Epoch  508 Sharpe:  tensor(2.3681)
# Epoch  509 Sharpe:  tensor(2.3681)
# Epoch  510 Sharpe:  tensor(2.3682)
# Epoch  511 Sharpe:  tensor(2.3682)
# Epoch  512 Sharpe:  tensor(2.3682)
# Epoch  513 Sharpe:  tensor(2.3682)
# Epoch  514 Sharpe:  tensor(2.3682)
# Epoch  515 Sharpe:  tensor(2.3683)
# Epoch  516 Sharpe:  tensor(2.3683)
# Epoch  517 Sharpe:  tensor(2.3683)
# Epoch  518 Sharpe:  tensor(2.3683)
# Epoch  519 Sharpe:  tensor(2.3683)
# Epoch  520 Sharpe:  tensor(2.3683)
# Epoch  521 Sharpe:  tensor(2.3684)
# Epoch  522 Sharpe:  tensor(2.3684)
# Epoch  523 Sharpe:  tensor(2.3684)
# Epoch  524 Sharpe:  tensor(2.3684)
# Epoch  525 Sharpe:  tensor(2.3684)
# Epoch  526 Sharpe:  tensor(2.3684)
# Epoch  527 Sharpe:  tensor(2.3684)
# Epoch  528 Sharpe:  tensor(2.3685)
# Epoch  529 Sharpe:  tensor(2.3685)
# Epoch  530 Sharpe:  tensor(2.3685)
# Epoch  531 Sharpe:  tensor(2.3685)
# Epoch  532 Sharpe:  tensor(2.3685)
# Epoch  533 Sharpe:  tensor(2.3685)
# Epoch  534 Sharpe:  tensor(2.3685)
# Epoch  535 Sharpe:  tensor(2.3685)
# Epoch  536 Sharpe:  tensor(2.3686)
# Epoch  537 Sharpe:  tensor(2.3686)
# Epoch  538 Sharpe:  tensor(2.3686)
# Epoch  539 Sharpe:  tensor(2.3686)
# Epoch  540 Sharpe:  tensor(2.3686)
# Epoch  541 Sharpe:  tensor(2.3686)
# Epoch  542 Sharpe:  tensor(2.3686)
# Epoch  543 Sharpe:  tensor(2.3686)
# Epoch  544 Sharpe:  tensor(2.3686)
# Epoch  545 Sharpe:  tensor(2.3687)
# Epoch  546 Sharpe:  tensor(2.3687)
# Epoch  547 Sharpe:  tensor(2.3687)
# Epoch  548 Sharpe:  tensor(2.3687)
# Epoch  549 Sharpe:  tensor(2.3687)
# Epoch  550 Sharpe:  tensor(2.3687)
# Epoch  551 Sharpe:  tensor(2.3687)
# Epoch  552 Sharpe:  tensor(2.3687)
# Epoch  553 Sharpe:  tensor(2.3687)
# Epoch  554 Sharpe:  tensor(2.3687)
# Epoch  555 Sharpe:  tensor(2.3688)
# Epoch  556 Sharpe:  tensor(2.3688)
# Epoch  557 Sharpe:  tensor(2.3688)
# Epoch  558 Sharpe:  tensor(2.3688)
# Epoch  559 Sharpe:  tensor(2.3688)
# Epoch  560 Sharpe:  tensor(2.3688)
# Epoch  561 Sharpe:  tensor(2.3688)
# Epoch  562 Sharpe:  tensor(2.3688)
# Epoch  563 Sharpe:  tensor(2.3688)
# Epoch  564 Sharpe:  tensor(2.3688)
# Epoch  565 Sharpe:  tensor(2.3688)
# Epoch  566 Sharpe:  tensor(2.3688)
# Epoch  567 Sharpe:  tensor(2.3689)
# Epoch  568 Sharpe:  tensor(2.3689)
# Epoch  569 Sharpe:  tensor(2.3689)
# Epoch  570 Sharpe:  tensor(2.3689)
# Epoch  571 Sharpe:  tensor(2.3689)
# Epoch  572 Sharpe:  tensor(2.3689)
# Epoch  573 Sharpe:  tensor(2.3689)
# Epoch  574 Sharpe:  tensor(2.3689)
# Epoch  575 Sharpe:  tensor(2.3689)
# Epoch  576 Sharpe:  tensor(2.3689)
# Epoch  577 Sharpe:  tensor(2.3689)
# Epoch  578 Sharpe:  tensor(2.3689)
# Epoch  579 Sharpe:  tensor(2.3689)
# Epoch  580 Sharpe:  tensor(2.3690)
# Epoch  581 Sharpe:  tensor(2.3690)
# Epoch  582 Sharpe:  tensor(2.3690)
# Epoch  583 Sharpe:  tensor(2.3690)
# Epoch  584 Sharpe:  tensor(2.3690)
# Epoch  585 Sharpe:  tensor(2.3690)
# Epoch  586 Sharpe:  tensor(2.3690)
# Epoch  587 Sharpe:  tensor(2.3690)
# Epoch  588 Sharpe:  tensor(2.3690)
# Epoch  589 Sharpe:  tensor(2.3690)
# Epoch  590 Sharpe:  tensor(2.3690)
# Epoch  591 Sharpe:  tensor(2.3690)
# Epoch  592 Sharpe:  tensor(2.3690)
# Epoch  593 Sharpe:  tensor(2.3690)
# Epoch  594 Sharpe:  tensor(2.3690)
# Epoch  595 Sharpe:  tensor(2.3690)
# Epoch  596 Sharpe:  tensor(2.3691)
# Epoch  597 Sharpe:  tensor(2.3691)
# Epoch  598 Sharpe:  tensor(2.3691)
# Epoch  599 Sharpe:  tensor(2.3691)
# Epoch  600 Sharpe:  tensor(2.3691)
# Epoch  601 Sharpe:  tensor(2.3691)
# Epoch  602 Sharpe:  tensor(2.3691)
# Epoch  603 Sharpe:  tensor(2.3691)
# Epoch  604 Sharpe:  tensor(2.3691)
# Epoch  605 Sharpe:  tensor(2.3691)
# Epoch  606 Sharpe:  tensor(2.3691)
# Epoch  607 Sharpe:  tensor(2.3691)
# Epoch  608 Sharpe:  tensor(2.3691)
# Epoch  609 Sharpe:  tensor(2.3691)
# Epoch  610 Sharpe:  tensor(2.3691)
# Epoch  611 Sharpe:  tensor(2.3691)
# Epoch  612 Sharpe:  tensor(2.3691)
# Epoch  613 Sharpe:  tensor(2.3691)
# Epoch  614 Sharpe:  tensor(2.3691)
# Epoch  615 Sharpe:  tensor(2.3692)
# Epoch  616 Sharpe:  tensor(2.3692)
# Epoch  617 Sharpe:  tensor(2.3692)
# Epoch  618 Sharpe:  tensor(2.3692)
# Epoch  619 Sharpe:  tensor(2.3692)
# Epoch  620 Sharpe:  tensor(2.3692)
# Epoch  621 Sharpe:  tensor(2.3692)
# Epoch  622 Sharpe:  tensor(2.3692)
# Epoch  623 Sharpe:  tensor(2.3692)
# Epoch  624 Sharpe:  tensor(2.3692)
# Epoch  625 Sharpe:  tensor(2.3692)
# Epoch  626 Sharpe:  tensor(2.3692)
# Epoch  627 Sharpe:  tensor(2.3692)
# Epoch  628 Sharpe:  tensor(2.3692)
# Epoch  629 Sharpe:  tensor(2.3692)
# Epoch  630 Sharpe:  tensor(2.3692)
# Epoch  631 Sharpe:  tensor(2.3692)
# Epoch  632 Sharpe:  tensor(2.3692)
# Epoch  633 Sharpe:  tensor(2.3692)
# Epoch  634 Sharpe:  tensor(2.3692)
# Epoch  635 Sharpe:  tensor(2.3692)
# Epoch  636 Sharpe:  tensor(2.3692)
# Epoch  637 Sharpe:  tensor(2.3692)
# Epoch  638 Sharpe:  tensor(2.3693)
# Epoch  639 Sharpe:  tensor(2.3693)
# Epoch  640 Sharpe:  tensor(2.3693)
# Epoch  641 Sharpe:  tensor(2.3693)
# Epoch  642 Sharpe:  tensor(2.3693)
# Epoch  643 Sharpe:  tensor(2.3693)
# Epoch  644 Sharpe:  tensor(2.3693)
# Epoch  645 Sharpe:  tensor(2.3693)
# Epoch  646 Sharpe:  tensor(2.3693)
# Epoch  647 Sharpe:  tensor(2.3693)
# Epoch  648 Sharpe:  tensor(2.3693)
# Epoch  649 Sharpe:  tensor(2.3693)
# Epoch  650 Sharpe:  tensor(2.3693)
# Epoch  651 Sharpe:  tensor(2.3693)
# Epoch  652 Sharpe:  tensor(2.3693)
# Epoch  653 Sharpe:  tensor(2.3693)
# Epoch  654 Sharpe:  tensor(2.3693)
# Epoch  655 Sharpe:  tensor(2.3693)
# Epoch  656 Sharpe:  tensor(2.3693)
# Epoch  657 Sharpe:  tensor(2.3693)
# Epoch  658 Sharpe:  tensor(2.3693)
# Epoch  659 Sharpe:  tensor(2.3693)
# Epoch  660 Sharpe:  tensor(2.3693)
# Epoch  661 Sharpe:  tensor(2.3693)
# Epoch  662 Sharpe:  tensor(2.3693)
# Epoch  663 Sharpe:  tensor(2.3693)
# Epoch  664 Sharpe:  tensor(2.3693)
# Epoch  665 Sharpe:  tensor(2.3693)
# Epoch  666 Sharpe:  tensor(2.3694)
# Epoch  667 Sharpe:  tensor(2.3694)
# Epoch  668 Sharpe:  tensor(2.3694)
# Epoch  669 Sharpe:  tensor(2.3694)
# Epoch  670 Sharpe:  tensor(2.3694)
# Epoch  671 Sharpe:  tensor(2.3694)
# Epoch  672 Sharpe:  tensor(2.3694)
# Epoch  673 Sharpe:  tensor(2.3694)
# Epoch  674 Sharpe:  tensor(2.3694)
# Epoch  675 Sharpe:  tensor(2.3694)
# Epoch  676 Sharpe:  tensor(2.3694)
# Epoch  677 Sharpe:  tensor(2.3694)
# Epoch  678 Sharpe:  tensor(2.3694)
# Epoch  679 Sharpe:  tensor(2.3694)
# Epoch  680 Sharpe:  tensor(2.3694)
# Epoch  681 Sharpe:  tensor(2.3694)
# Epoch  682 Sharpe:  tensor(2.3694)
# Epoch  683 Sharpe:  tensor(2.3694)
# Epoch  684 Sharpe:  tensor(2.3694)
# Epoch  685 Sharpe:  tensor(2.3694)
# Epoch  686 Sharpe:  tensor(2.3694)
# Epoch  687 Sharpe:  tensor(2.3694)
# Epoch  688 Sharpe:  tensor(2.3694)
# Epoch  689 Sharpe:  tensor(2.3694)
# Epoch  690 Sharpe:  tensor(2.3694)
# Epoch  691 Sharpe:  tensor(2.3694)
# Epoch  692 Sharpe:  tensor(2.3694)
# Epoch  693 Sharpe:  tensor(2.3694)
# Epoch  694 Sharpe:  tensor(2.3694)
# Epoch  695 Sharpe:  tensor(2.3694)
# Epoch  696 Sharpe:  tensor(2.3694)
# Epoch  697 Sharpe:  tensor(2.3694)
# Epoch  698 Sharpe:  tensor(2.3694)
# Epoch  699 Sharpe:  tensor(2.3694)
# Epoch  700 Sharpe:  tensor(2.3694)
# Epoch  701 Sharpe:  tensor(2.3695)
# Epoch  702 Sharpe:  tensor(2.3695)
# Epoch  703 Sharpe:  tensor(2.3695)
# Epoch  704 Sharpe:  tensor(2.3695)
# Epoch  705 Sharpe:  tensor(2.3695)
# Epoch  706 Sharpe:  tensor(2.3695)
# Epoch  707 Sharpe:  tensor(2.3695)
# Epoch  708 Sharpe:  tensor(2.3695)
# Epoch  709 Sharpe:  tensor(2.3695)
# Epoch  710 Sharpe:  tensor(2.3695)
# Epoch  711 Sharpe:  tensor(2.3695)
# Epoch  712 Sharpe:  tensor(2.3695)
# Epoch  713 Sharpe:  tensor(2.3695)
# Epoch  714 Sharpe:  tensor(2.3695)
# Epoch  715 Sharpe:  tensor(2.3695)
# Epoch  716 Sharpe:  tensor(2.3695)
# Epoch  717 Sharpe:  tensor(2.3695)
# Epoch  718 Sharpe:  tensor(2.3695)
# Epoch  719 Sharpe:  tensor(2.3695)
# Epoch  720 Sharpe:  tensor(2.3695)
# Epoch  721 Sharpe:  tensor(2.3695)
# Epoch  722 Sharpe:  tensor(2.3695)
# Epoch  723 Sharpe:  tensor(2.3695)
# Epoch  724 Sharpe:  tensor(2.3695)
# Epoch  725 Sharpe:  tensor(2.3695)
# Epoch  726 Sharpe:  tensor(2.3695)
# Epoch  727 Sharpe:  tensor(2.3695)
# Epoch  728 Sharpe:  tensor(2.3695)
# Epoch  729 Sharpe:  tensor(2.3695)
# Epoch  730 Sharpe:  tensor(2.3695)
# Epoch  731 Sharpe:  tensor(2.3695)
# Epoch  732 Sharpe:  tensor(2.3695)
# Epoch  733 Sharpe:  tensor(2.3695)
# Epoch  734 Sharpe:  tensor(2.3695)
# Epoch  735 Sharpe:  tensor(2.3695)
# Epoch  736 Sharpe:  tensor(2.3695)
# Epoch  737 Sharpe:  tensor(2.3695)
# Epoch  738 Sharpe:  tensor(2.3695)
# Epoch  739 Sharpe:  tensor(2.3695)
# Epoch  740 Sharpe:  tensor(2.3695)
# Epoch  741 Sharpe:  tensor(2.3695)
# Epoch  742 Sharpe:  tensor(2.3695)
# Epoch  743 Sharpe:  tensor(2.3695)
# Epoch  744 Sharpe:  tensor(2.3695)
# Epoch  745 Sharpe:  tensor(2.3695)
# Epoch  746 Sharpe:  tensor(2.3696)
# Epoch  747 Sharpe:  tensor(2.3696)
# Epoch  748 Sharpe:  tensor(2.3696)
# Epoch  749 Sharpe:  tensor(2.3696)
# Epoch  750 Sharpe:  tensor(2.3696)
# Epoch  751 Sharpe:  tensor(2.3696)
# Epoch  752 Sharpe:  tensor(2.3696)
# Epoch  753 Sharpe:  tensor(2.3696)
# Epoch  754 Sharpe:  tensor(2.3696)
# Epoch  755 Sharpe:  tensor(2.3696)
# Epoch  756 Sharpe:  tensor(2.3696)
# Epoch  757 Sharpe:  tensor(2.3696)
# Epoch  758 Sharpe:  tensor(2.3696)
# Epoch  759 Sharpe:  tensor(2.3696)
# Epoch  760 Sharpe:  tensor(2.3696)
# Epoch  761 Sharpe:  tensor(2.3696)
# Epoch  762 Sharpe:  tensor(2.3696)
# Epoch  763 Sharpe:  tensor(2.3696)
# Epoch  764 Sharpe:  tensor(2.3696)
# Epoch  765 Sharpe:  tensor(2.3696)
# Epoch  766 Sharpe:  tensor(2.3696)
# Epoch  767 Sharpe:  tensor(2.3696)
# Epoch  768 Sharpe:  tensor(2.3696)
# Epoch  769 Sharpe:  tensor(2.3696)
# Epoch  770 Sharpe:  tensor(2.3696)
# Epoch  771 Sharpe:  tensor(2.3696)
# Epoch  772 Sharpe:  tensor(2.3696)
# Epoch  773 Sharpe:  tensor(2.3696)
# Epoch  774 Sharpe:  tensor(2.3696)
# Epoch  775 Sharpe:  tensor(2.3696)
# Epoch  776 Sharpe:  tensor(2.3696)
# Epoch  777 Sharpe:  tensor(2.3696)
# Epoch  778 Sharpe:  tensor(2.3696)
# Epoch  779 Sharpe:  tensor(2.3696)
# Epoch  780 Sharpe:  tensor(2.3696)
# Epoch  781 Sharpe:  tensor(2.3696)
# Epoch  782 Sharpe:  tensor(2.3696)
# Epoch  783 Sharpe:  tensor(2.3696)
# Epoch  784 Sharpe:  tensor(2.3696)
# Epoch  785 Sharpe:  tensor(2.3696)
# Epoch  786 Sharpe:  tensor(2.3696)
# Epoch  787 Sharpe:  tensor(2.3696)
# Epoch  788 Sharpe:  tensor(2.3696)
# Epoch  789 Sharpe:  tensor(2.3696)
# Epoch  790 Sharpe:  tensor(2.3696)
# Epoch  791 Sharpe:  tensor(2.3696)
# Epoch  792 Sharpe:  tensor(2.3696)
# Epoch  793 Sharpe:  tensor(2.3696)
# Epoch  794 Sharpe:  tensor(2.3696)
# Epoch  795 Sharpe:  tensor(2.3696)
# Epoch  796 Sharpe:  tensor(2.3696)
# Epoch  797 Sharpe:  tensor(2.3696)
# Epoch  798 Sharpe:  tensor(2.3696)
# Epoch  799 Sharpe:  tensor(2.3696)
# Epoch  800 Sharpe:  tensor(2.3696)
# Epoch  801 Sharpe:  tensor(2.3696)
# Epoch  802 Sharpe:  tensor(2.3696)
# Epoch  803 Sharpe:  tensor(2.3696)
# Epoch  804 Sharpe:  tensor(2.3697)
# Epoch  805 Sharpe:  tensor(2.3697)
# Epoch  806 Sharpe:  tensor(2.3697)
# Epoch  807 Sharpe:  tensor(2.3697)
# Epoch  808 Sharpe:  tensor(2.3697)
# Epoch  809 Sharpe:  tensor(2.3697)
# Epoch  810 Sharpe:  tensor(2.3697)
# Epoch  811 Sharpe:  tensor(2.3697)
# Epoch  812 Sharpe:  tensor(2.3697)
# Epoch  813 Sharpe:  tensor(2.3697)
# Epoch  814 Sharpe:  tensor(2.3697)
# Epoch  815 Sharpe:  tensor(2.3697)
# Epoch  816 Sharpe:  tensor(2.3697)
# Epoch  817 Sharpe:  tensor(2.3697)
# Epoch  818 Sharpe:  tensor(2.3697)
# Epoch  819 Sharpe:  tensor(2.3697)
# Epoch  820 Sharpe:  tensor(2.3697)
# Epoch  821 Sharpe:  tensor(2.3697)
# Epoch  822 Sharpe:  tensor(2.3697)
# Epoch  823 Sharpe:  tensor(2.3697)
# Epoch  824 Sharpe:  tensor(2.3697)
# Epoch  825 Sharpe:  tensor(2.3697)
# Epoch  826 Sharpe:  tensor(2.3697)
# Epoch  827 Sharpe:  tensor(2.3697)
# Epoch  828 Sharpe:  tensor(2.3697)
# Epoch  829 Sharpe:  tensor(2.3697)
# Epoch  830 Sharpe:  tensor(2.3697)
# Epoch  831 Sharpe:  tensor(2.3697)
# Epoch  832 Sharpe:  tensor(2.3697)
# Epoch  833 Sharpe:  tensor(2.3697)
# Epoch  834 Sharpe:  tensor(2.3697)
# Epoch  835 Sharpe:  tensor(2.3697)
# Epoch  836 Sharpe:  tensor(2.3697)
# Epoch  837 Sharpe:  tensor(2.3697)
# Epoch  838 Sharpe:  tensor(2.3697)
# Epoch  839 Sharpe:  tensor(2.3697)
# Epoch  840 Sharpe:  tensor(2.3697)
# Epoch  841 Sharpe:  tensor(2.3697)
# Epoch  842 Sharpe:  tensor(2.3697)
# Epoch  843 Sharpe:  tensor(2.3697)
# Epoch  844 Sharpe:  tensor(2.3697)
# Epoch  845 Sharpe:  tensor(2.3697)
# Epoch  846 Sharpe:  tensor(2.3697)
# Epoch  847 Sharpe:  tensor(2.3697)
# Epoch  848 Sharpe:  tensor(2.3697)
# Epoch  849 Sharpe:  tensor(2.3697)
# Epoch  850 Sharpe:  tensor(2.3697)
# Epoch  851 Sharpe:  tensor(2.3697)
# Epoch  852 Sharpe:  tensor(2.3697)
# Epoch  853 Sharpe:  tensor(2.3697)
# Epoch  854 Sharpe:  tensor(2.3697)
# Epoch  855 Sharpe:  tensor(2.3697)
# Epoch  856 Sharpe:  tensor(2.3697)
# Epoch  857 Sharpe:  tensor(2.3697)
# Epoch  858 Sharpe:  tensor(2.3697)
# Epoch  859 Sharpe:  tensor(2.3697)
# Epoch  860 Sharpe:  tensor(2.3697)
# Epoch  861 Sharpe:  tensor(2.3697)
# Epoch  862 Sharpe:  tensor(2.3697)
# Epoch  863 Sharpe:  tensor(2.3697)
# Epoch  864 Sharpe:  tensor(2.3697)
# Epoch  865 Sharpe:  tensor(2.3697)
# Epoch  866 Sharpe:  tensor(2.3697)
# Epoch  867 Sharpe:  tensor(2.3697)
# Epoch  868 Sharpe:  tensor(2.3697)
# Epoch  869 Sharpe:  tensor(2.3697)
# Epoch  870 Sharpe:  tensor(2.3697)
# Epoch  871 Sharpe:  tensor(2.3697)
# Epoch  873 Sharpe:  tensor(2.3697)
# Epoch  874 Sharpe:  tensor(2.3697)
# Epoch  875 Sharpe:  tensor(2.3697)
# Epoch  876 Sharpe:  tensor(2.3697)
# Epoch  877 Sharpe:  tensor(2.3697)
# Epoch  878 Sharpe:  tensor(2.3697)
# Epoch  879 Sharpe:  tensor(2.3697)
# Epoch  880 Sharpe:  tensor(2.3697)
# Epoch  881 Sharpe:  tensor(2.3697)
# Epoch  882 Sharpe:  tensor(2.3697)
# Epoch  883 Sharpe:  tensor(2.3698)
# Epoch  884 Sharpe:  tensor(2.3698)
# Epoch  885 Sharpe:  tensor(2.3698)
# Epoch  886 Sharpe:  tensor(2.3698)
# Epoch  887 Sharpe:  tensor(2.3698)
# Epoch  888 Sharpe:  tensor(2.3698)
# Epoch  889 Sharpe:  tensor(2.3698)
# Epoch  890 Sharpe:  tensor(2.3698)
# Epoch  891 Sharpe:  tensor(2.3698)
# Epoch  892 Sharpe:  tensor(2.3698)
# Epoch  893 Sharpe:  tensor(2.3698)
# Epoch  894 Sharpe:  tensor(2.3698)
# Epoch  895 Sharpe:  tensor(2.3698)
# Epoch  896 Sharpe:  tensor(2.3698)
# Epoch  897 Sharpe:  tensor(2.3698)
# Epoch  898 Sharpe:  tensor(2.3698)
# Epoch  899 Sharpe:  tensor(2.3698)
# Epoch  900 Sharpe:  tensor(2.3698)
# Epoch  901 Sharpe:  tensor(2.3698)
# Epoch  902 Sharpe:  tensor(2.3698)
# Epoch  903 Sharpe:  tensor(2.3698)
# Epoch  904 Sharpe:  tensor(2.3698)
# Epoch  905 Sharpe:  tensor(2.3698)
# Epoch  906 Sharpe:  tensor(2.3698)
# Epoch  907 Sharpe:  tensor(2.3698)
# Epoch  908 Sharpe:  tensor(2.3698)
# Epoch  909 Sharpe:  tensor(2.3698)
# Epoch  910 Sharpe:  tensor(2.3698)
# Epoch  911 Sharpe:  tensor(2.3698)
# Epoch  912 Sharpe:  tensor(2.3698)
# Epoch  913 Sharpe:  tensor(2.3698)
# Epoch  914 Sharpe:  tensor(2.3698)
# Epoch  915 Sharpe:  tensor(2.3698)
# Epoch  916 Sharpe:  tensor(2.3698)
# Epoch  917 Sharpe:  tensor(2.3698)
# Epoch  918 Sharpe:  tensor(2.3698)
# Epoch  919 Sharpe:  tensor(2.3698)
# Epoch  920 Sharpe:  tensor(2.3698)
# Epoch  921 Sharpe:  tensor(2.3698)
# Epoch  922 Sharpe:  tensor(2.3698)
# Epoch  923 Sharpe:  tensor(2.3698)
# Epoch  924 Sharpe:  tensor(2.3698)
# Epoch  925 Sharpe:  tensor(2.3698)
# Epoch  926 Sharpe:  tensor(2.3698)
# Epoch  927 Sharpe:  tensor(2.3698)
# Epoch  928 Sharpe:  tensor(2.3698)
# Epoch  929 Sharpe:  tensor(2.3698)
# Epoch  930 Sharpe:  tensor(2.3698)
# Epoch  931 Sharpe:  tensor(2.3698)
# Epoch  932 Sharpe:  tensor(2.3698)
# Epoch  933 Sharpe:  tensor(2.3698)
# Epoch  934 Sharpe:  tensor(2.3698)
# Epoch  935 Sharpe:  tensor(2.3698)
# Epoch  936 Sharpe:  tensor(2.3698)
# Epoch  937 Sharpe:  tensor(2.3698)
# Epoch  938 Sharpe:  tensor(2.3698)
# Epoch  939 Sharpe:  tensor(2.3698)
# Epoch  940 Sharpe:  tensor(2.3698)
# Epoch  941 Sharpe:  tensor(2.3698)
# Epoch  942 Sharpe:  tensor(2.3698)
# Epoch  943 Sharpe:  tensor(2.3698)
# Epoch  944 Sharpe:  tensor(2.3698)
# Epoch  945 Sharpe:  tensor(2.3698)
# Epoch  946 Sharpe:  tensor(2.3698)
# Epoch  947 Sharpe:  tensor(2.3698)
# Epoch  948 Sharpe:  tensor(2.3698)
# Epoch  949 Sharpe:  tensor(2.3698)
# Epoch  950 Sharpe:  tensor(2.3698)
# Epoch  951 Sharpe:  tensor(2.3698)
# Epoch  952 Sharpe:  tensor(2.3698)
# Epoch  953 Sharpe:  tensor(2.3698)
# Epoch  954 Sharpe:  tensor(2.3698)
# Epoch  955 Sharpe:  tensor(2.3698)
# Epoch  956 Sharpe:  tensor(2.3698)
# Epoch  957 Sharpe:  tensor(2.3698)
# Epoch  958 Sharpe:  tensor(2.3698)
# Epoch  959 Sharpe:  tensor(2.3698)
# Epoch  960 Sharpe:  tensor(2.3698)
# Epoch  961 Sharpe:  tensor(2.3698)
# Epoch  962 Sharpe:  tensor(2.3698)
# Epoch  963 Sharpe:  tensor(2.3698)
# Epoch  964 Sharpe:  tensor(2.3698)
# Epoch  965 Sharpe:  tensor(2.3698)
# Epoch  966 Sharpe:  tensor(2.3698)
# Epoch  967 Sharpe:  tensor(2.3698)
# Epoch  968 Sharpe:  tensor(2.3698)
# Epoch  969 Sharpe:  tensor(2.3698)
# Epoch  970 Sharpe:  tensor(2.3698)
# Epoch  971 Sharpe:  tensor(2.3698)
# Epoch  972 Sharpe:  tensor(2.3698)
# Epoch  973 Sharpe:  tensor(2.3698)
# Epoch  974 Sharpe:  tensor(2.3698)
# Epoch  975 Sharpe:  tensor(2.3698)
# Epoch  976 Sharpe:  tensor(2.3698)
# Epoch  977 Sharpe:  tensor(2.3698)
# Epoch  978 Sharpe:  tensor(2.3698)
# Epoch  979 Sharpe:  tensor(2.3698)
# Epoch  980 Sharpe:  tensor(2.3698)
# Epoch  981 Sharpe:  tensor(2.3698)
# Epoch  982 Sharpe:  tensor(2.3698)
# Epoch  983 Sharpe:  tensor(2.3698)
# Epoch  984 Sharpe:  tensor(2.3698)
# Epoch  985 Sharpe:  tensor(2.3698)
# Epoch  986 Sharpe:  tensor(2.3698)
# Epoch  987 Sharpe:  tensor(2.3698)
# Epoch  988 Sharpe:  tensor(2.3698)
# Epoch  989 Sharpe:  tensor(2.3698)
# Epoch  990 Sharpe:  tensor(2.3698)
# Epoch  991 Sharpe:  tensor(2.3698)
# Epoch  992 Sharpe:  tensor(2.3698)
# Epoch  993 Sharpe:  tensor(2.3698)
# Epoch  994 Sharpe:  tensor(2.3698)
# Epoch  995 Sharpe:  tensor(2.3698)
# Epoch  996 Sharpe:  tensor(2.3698)
# Epoch  997 Sharpe:  tensor(2.3698)
# Epoch  998 Sharpe:  tensor(2.3698)
# Epoch  999 Sharpe:  tensor(2.3698)

# %% [markdown]
# ## 4. Visualization

# %%
print('Cum_return_train',Cum_return_train[-1])
plt.rcParams['figure.figsize'] = [7, 3]
# plt.title("sharp's ratio optimization RRL")
plt.plot(rewards)
# plt.ylim((-0.5,0.5))
# plt.legend(['sharp\'s ratio(RRL):M=10,layer=3'],loc='upper left')
plt.savefig("SRRRL20-3.png", dpi=300)
plt.show()

plt.rcParams['figure.figsize'] = [15, 8]
f, axes = plt.subplots(3, 1, sharex=True)
# plt.suptitle("BTC RRL Train", fontsize=16)

axes[0].set_ylabel("Prices")
axes[0].plot(prices[M:M+T])
axes[1].set_ylabel("Strategy Returns")
axes[1].plot(Cum_return_train.detach().numpy())
axes[2].set_ylabel("Ft")
axes[2].bar(list(range(len(Cum_return_train))), Ft[:-1].detach().numpy())
# plt.legend(['Train(RRL):M=10,layer=3'],loc='upper left')
plt.savefig("TrainRRL20-3.png", dpi=300)
plt.show()
# Out:
# Cum_return_train tensor(78243.8672, grad_fn=<SelectBackward>)

# %%
# data:M+T:M+T+N+1
prices_test = np.array(raw_prices[1])[OFFSET+M+T:]
asset_returns_test = asset_returns[:M+N+1]
scaler = StandardScaler()
normalized_asset_returns_test = torch.tensor(scaler.fit_transform(asset_returns_test[:M+N+1][:, None])[:, 0]).to(torch.float32)
# normalized_asset_returns_test = normalized_asset_returns[M+T:T+M+N+1]
# print(asset_returns_test,normalized_asset_returns_test)

rewards_test = []
Ft_test = torch.zeros(N).to(normalized_asset_returns_test.device)
for i in range(1, N):
    data_test = normalized_asset_returns_test[i-1:i+M-1]
    input_test = data_test.view(1,M,1).to(device)
    Ft_test[i] = model(input_test)
    returns_test = miu * (Ft_test[:N-1] * asset_returns_test[M:M+N-1]) - (delta * torch.abs(Ft_test[1:] - Ft_test[:N-1]))
    expected_return_test = torch.mean(returns_test, dim=-1)
    std_return_test = torch.std(returns_test, dim=-1)
    sharpe_test = expected_return_test / (torch.sqrt(std_return_test) + eps)
    rewards_test.append(sharpe_test.detach().cpu())
    Cum_return_tests = returns_test.cumsum(dim=-1)
# print('rewards_test',rewards_test)
print('Cum_return_test',Cum_return_tests[-1])
# Out:
# Cum_return_test tensor(-385.9592, grad_fn=<SelectBackward>)

# %%
plt.rcParams['figure.figsize'] = [15, 8]
f, axes = plt.subplots(4, 1, sharex=True)
axes[0].set_ylabel("Prices")
axes[0].plot(prices_test[M:M+N+1])
axes[1].set_ylabel("Strategy Returns")
axes[1].plot(Cum_return_tests.detach().numpy())
axes[2].set_ylabel("Sharpe ratio")
axes[2].plot(rewards_test)
axes[3].set_ylabel("Ft")
axes[3].bar(list(range(len(Cum_return_tests))), Ft_test[:-1].detach().numpy())
plt.savefig("TestRRL20-3.png", dpi=300)
plt.show()
